# %%
import pandas as pd
import gensim
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# #### Fetching preprocessed data

# %%
preprocessed_data=pd.read_csv('Preprocessed_Transcripts_28012020160602.csv')

# %%
preprocessed_data.head()
# Out:
#      Call_ID                                    Raw Transcripts  \
# 0   56482635  Welcome to HDFC life my name is Kai how may I ...
# 1   61876574  Good afternoon, HDFC Life customer care. This ...
# 2   85550179  Good morning. Welcome to HDFC insurance? How c...
# 3   98762981  Good afternoon.\rHDFC life customer care this ...
# 4  114965010  Graph noon AGC life customer care. This is Ale...
#
#                             Preprocessed Transcripts
# 0  ['welcome', 'life', 'help', 'hello', 'child', ...
# 1  ['good', 'afternoon', 'customer', 'care', 'hel...
# 2  ['good', 'morning', 'welcome', 'insurance', 'h...
# 3  ['good', 'afternoon', 'customer', 'care', 'hel...
# 4  ['graph', 'noon', 'life', 'customer', 'care', ...

# %% [markdown]
# #### Tokenizing preprocessed transcripts to be used for genism dictionary

# %%
tokenising=[]
for text in preprocessed_data['Preprocessed Transcripts']:
    tokenising.append(gensim.utils.simple_preprocess(text))

# %%
preprocessed_data['tokenised']= tokenising

# %% [markdown]
# #### Creating the dictionary object that maps each tokenized word to a unique id

# %%
dictionary = gensim.corpora.Dictionary(preprocessed_data['tokenised'])

# %%
'''
Checking dictionary created
'''
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 50:
        break
# Out:
# 0 account
# 1 alright
# 2 angel
# 3 assist
# 4 check
# 5 child
# 6 chill
# 7 continuous
# 8 easy
# 9 facility
# 10 fine
# 11 hello
# 12 help
# 13 icsi
# 14 inform
# 15 insurance
# 16 know
# 17 life
# 18 line
# 19 link
# 20 maybe
# 21 phone
# 22 pleasant
# 23 policy
# 24 policy_number
# 25 post
# 26 procedure
# 27 process
# 28 purpose
# 29 register
# 30 registering
# 31 registration
# 32 second
# 33 section
# 34 service
# 35 space
# 36 summary
# 37 time
# 38 type
# 39 unit
# 40 update
# 41 value
# 42 verification
# 43 want
# 44 welcome
# 45 afternoon
# 46 agent
# 47 agree
# 48 benefit
# 49 card
# 50 care

# %% [markdown]
# #### Creating corpus (bag of words) -  a corpus contains each word’s id and its frequency count in that document

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_data['tokenised']]

# %%
'''
Preview BOW for our sample preprocessed document
'''
document_num = 1
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 2 ("angel") appears 1 time.
# Word 8 ("easy") appears 1 time.
# Word 12 ("help") appears 3 time.
# Word 16 ("know") appears 4 time.
# Word 26 ("procedure") appears 1 time.
# Word 29 ("register") appears 1 time.
# Word 43 ("want") appears 4 time.
# Word 45 ("afternoon") appears 1 time.
# Word 46 ("agent") appears 1 time.
# Word 47 ("agree") appears 1 time.
# Word 48 ("benefit") appears 1 time.
# Word 49 ("card") appears 2 time.
# Word 50 ("care") appears 1 time.
# Word 51 ("collect") appears 1 time.
# Word 52 ("come") appears 1 time.
# Word 53 ("confirmation") appears 1 time.
# Word 54 ("contact") appears 2 time.
# Word 55 ("customer") appears 1 time.
# Word 56 ("document") appears 2 time.
# Word 57 ("easily") appears 1 time.
# Word 58 ("enroll") appears 2 time.
# Word 59 ("everybody") appears 1 time.
# Word 60 ("good") appears 1 time.
# Word 61 ("graph") appears 1 time.
# Word 62 ("great") appears 1 time.
# Word 63 ("immediately") appears 1 time.
# Word 64 ("information") appears 2 time.
# Word 65 ("mail") appears 1 time.
# Word 66 ("mention") appears 1 time.
# Word 67 ("minimum") appears 1 time.
# Word 68 ("mobile_number") appears 2 time.
# Word 69 ("need") appears 3 time.
# Word 70 ("online") appears 2 time.
# Word 71 ("option") appears 1 time.
# Word 72 ("passport") appears 1 time.
# Word 73 ("photo") appears 1 time.
# Word 74 ("plan") appears 2 time.
# Word 75 ("premium") appears 2 time.
# Word 76 ("problem") appears 1 time.
# Word 77 ("processor") appears 1 time.
# Word 78 ("query") appears 1 time.
# Word 79 ("ratehdfclife") appears 1 time.
# Word 80 ("size") appears 1 time.
# Word 81 ("today") appears 1 time.
# Word 82 ("touch") appears 1 time.
# Word 83 ("understand") appears 1 time.
# Word 84 ("unit_link") appears 2 time.
# Word 85 ("upload") appears 2 time.
# Word 86 ("website") appears 2 time.
# Word 87 ("write") appears 1 time.
# Word 88 ("yeah_sure") appears 2 time.
# Word 89 ("yearly") appears 1 time.

# %% [markdown]
# #### Multi core Gensim LDA model on transcript

# %%
'''
Train your lda model using gensim.models.LdaMulticore and save it to 'lda_model'
'''
# TODO
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dictionary,                                    
                                   passes =5,
                                   workers = 1)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.037*"plan" + 0.030*"know" + 0.030*"premium" + 0.027*"payment" + 0.024*"help" + 0.022*"want" + 0.015*"benefit" + 0.014*"good" + 0.013*"life" + 0.011*"time"
#
#
# Topic: 1
# Words: 0.056*"policy" + 0.027*"know" + 0.024*"want" + 0.018*"premium" + 0.017*"help" + 0.013*"benefit" + 0.012*"assignment" + 0.010*"click" + 0.009*"type" + 0.009*"contact"
#
#
# Topic: 2
# Words: 0.026*"claim" + 0.026*"know" + 0.026*"help" + 0.024*"want" + 0.018*"plan" + 0.017*"agent" + 0.017*"number" + 0.016*"need" + 0.015*"online" + 0.014*"policy_number"
#
#
# Topic: 3
# Words: 0.038*"policy" + 0.026*"policy_number" + 0.025*"help" + 0.023*"know" + 0.022*"check" + 0.016*"need" + 0.015*"want" + 0.012*"register" + 0.011*"insurance" + 0.011*"sorry"

# %% [markdown]
# ##### Perplexity and Coherence

# %%
print('\nPerplexity Score: ', lda_model.log_perplexity(bow_corpus))
# Out:
# Perplexity Score:  -5.949112015203176

# %%
# Compute Coherence Score
coherence_model_lda = gensim.models.CoherenceModel(model=lda_model, texts=preprocessed_data['tokenised'], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.25349447394426916

# %%
doc_lda = lda_model[bow_corpus]
for topic in doc_lda:
     print("Document Topics      : ", topic)
# Out:
# Document Topics      :  [(2, 0.99509585)]
# Document Topics      :  [(4, 0.99589247)]
# Document Topics      :  [(4, 0.99518335)]
# Document Topics      :  [(0, 0.9951229)]
# Document Topics      :  [(2, 0.995408)]
# Document Topics      :  [(4, 0.995648)]
# Document Topics      :  [(0, 0.9959039)]
# Document Topics      :  [(1, 0.99553454)]
# Document Topics      :  [(0, 0.9968037)]
# Document Topics      :  [(2, 0.99379224)]
# Document Topics      :  [(1, 0.9956531)]
# Document Topics      :  [(0, 0.9958857)]
# Document Topics      :  [(4, 0.99279404)]
# Document Topics      :  [(0, 0.9949156)]
# Document Topics      :  [(1, 0.99478745)]
# Document Topics      :  [(2, 0.99443704)]
# Document Topics      :  [(1, 0.99509674)]
# Document Topics      :  [(1, 0.9960071)]
# Document Topics      :  [(1, 0.9935154)]
# Document Topics      :  [(0, 0.9964995)]
# Document Topics      :  [(4, 0.99481297)]
# Document Topics      :  [(3, 0.99546427)]
# Document Topics      :  [(3, 0.9949249)]
# Document Topics      :  [(1, 0.99523324)]
# Document Topics      :  [(2, 0.9960206)]
# Document Topics      :  [(0, 0.995638)]
# Document Topics      :  [(2, 0.994537)]
# Document Topics      :  [(2, 0.9944505)]
# Document Topics      :  [(1, 0.99322104)]
# Document Topics      :  [(3, 0.9965436)]
# Document Topics      :  [(2, 0.9953258)]
# Document Topics      :  [(2, 0.9937512)]
# Document Topics      :  [(2, 0.9946299)]
# Document Topics      :  [(1, 0.993828)]
# Document Topics      :  [(0, 0.99599)]
# Document Topics      :  [(2, 0.9949629)]
# Document Topics      :  [(3, 0.9948291)]
# Document Topics      :  [(1, 0.9944518)]
# Document Topics      :  [(0, 0.9959755)]
# Document Topics      :  [(2, 0.9933922)]
# Document Topics      :  [(2, 0.9946221)]
# Document Topics      :  [(2, 0.99351144)]
# Document Topics      :  [(4, 0.99389535)]
# Document Topics      :  [(2, 0.994065)]
# Document Topics      :  [(1, 0.99516886)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(2, 0.9949815)]
# Document Topics      :  [(1, 0.99624985)]
# Document Topics      :  [(1, 0.9922405)]
# Document Topics      :  [(2, 0.993985)]
# Document Topics      :  [(0, 0.99491525)]
# Document Topics      :  [(4, 0.9955263)]
# Document Topics      :  [(2, 0.9946191)]
# Document Topics      :  [(4, 0.99395597)]
# Document Topics      :  [(0, 0.99497235)]
# Document Topics      :  [(1, 0.9934361)]
# Document Topics      :  [(0, 0.9953062)]
# Document Topics      :  [(1, 0.99530244)]
# Document Topics      :  [(3, 0.99541813)]
# Document Topics      :  [(1, 0.9948825)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(1, 0.9958289)]
# Document Topics      :  [(1, 0.994416)]
# Document Topics      :  [(0, 0.99581116)]
# Document Topics      :  [(2, 0.9952315)]
# Document Topics      :  [(0, 0.9957388)]
# Document Topics      :  [(2, 0.9943342)]
# Document Topics      :  [(2, 0.99453115)]
# Document Topics      :  [(4, 0.9960076)]
# Document Topics      :  [(0, 0.9921482)]
# Document Topics      :  [(2, 0.9929921)]
# Document Topics      :  [(2, 0.994239)]
# Document Topics      :  [(3, 0.9959648)]
# Document Topics      :  [(0, 0.36781436), (2, 0.6285906)]
# Document Topics      :  [(2, 0.995408)]
# Document Topics      :  [(0, 0.9958082)]
# Document Topics      :  [(4, 0.994327)]
# Document Topics      :  [(4, 0.9945495)]
# Document Topics      :  [(3, 0.99489653)]
# Document Topics      :  [(2, 0.99529076)]
# Document Topics      :  [(2, 0.99451053)]
# Document Topics      :  [(0, 0.9952773)]
# Document Topics      :  [(3, 0.9945227)]
# Document Topics      :  [(2, 0.9957207)]
# Document Topics      :  [(2, 0.9947015)]
# Document Topics      :  [(1, 0.99565303)]
# Document Topics      :  [(2, 0.9944803)]
# Document Topics      :  [(4, 0.9927143)]
# Document Topics      :  [(1, 0.9942908)]
# Document Topics      :  [(2, 0.9966435)]
# Document Topics      :  [(4, 0.9952324)]

# %% [markdown]
# ### LDA with bigrams

# %%
# Getting bigrams  
vectorizer = CountVectorizer(ngram_range = (2,2))

# %%
X1=vectorizer.fit_transform(preprocessed_data['Preprocessed Transcripts'])

# %%
bigrams=[]
for text in preprocessed_data['Preprocessed Transcripts']:
    text=[text,]
    X1=(vectorizer.fit_transform(text))
    bigrams.append(vectorizer.get_feature_names())

# %%
bigrams
# Out:
# [['account register',
#   'alright unit',
#   'angel policy_number',
#   'assist maybe',
#   'check phone',
#   'check value',
#   'child policy',
#   'chill insurance',
#   'continuous update',
#   'easy time',
#   'facility registration_process',
#   'fine register',
#   'hello child',
#   'help hello',
#   'icsi insurance',
#   'inform assist',
#   'insurance registering',
#   'insurance verification',
#   'know check',
#   'know policy_number',
#   'life help',
#   'life pleasant',
#   'line register',
#   'link policy',
#   'maybe registration_process',
#   'phone value',
#   'policy chill',
#   'policy policy',
#   'policy summary',
#   'policy want',
#   'policy_number alright',
#   'policy_number angel',
#   'policy_number second',
#   'post continuous',
#   'procedure easy',
#   'process post',
#   'purpose know',
#   'register facility',
#   'register line',
#   'register service',
#   'registering procedure',
#   'registration process',
#   'registration_process icsi',
#   'registration_process life',
#   'second check',
#   'section account',
#   'service type',
#   'space policy_number',
#   'summary section',
#   'time registration',
#   'type space',
#   'unit link',
#   'update fine',
#   'value policy',
#   'verification purpose',
#   'want inform',
#   'want know',
#   'welcome life'],
#  ['afternoon customer',
#   'agent touch',
#   'agree confirmation',
#   'angel mobile_number',
#   'benefit agree',
#   'card card',
#   'card photo',
#   'care help',
#   'collect document',
#   'come collect',
#   'confirmation minimum',
#   'contact write',
#   'contact yeah_sure',
#   'customer care',
#   'document need',
#   'document online',
#   'easily agent',
#   'easy online',
#   'enroll easily',
#   'enroll immediately',
#   'everybody understand',
#   'good afternoon',
#   'graph passport',
#   'help know',
#   'help today',
#   'help yeah_sure',
#   'immediately enroll',
#   'information help',
#   'information unit_link',
#   'know premium',
#   'know problem',
#   'know procedure',
#   'know want',
#   'mail query',
#   'mention document',
#   'minimum premium',
#   'mobile_number angel',
#   'mobile_number want',
#   'need card',
#   'need upload',
#   'online easy',
#   'online processor',
#   'option register',
#   'passport size',
#   'photo graph',
#   'plan help',
#   'plan know',
#   'premium benefit',
#   'premium yearly',
#   'problem contact',
#   'procedure enroll',
#   'processor mention',
#   'query ratehdfclife',
#   'ratehdfclife great',
#   'register need',
#   'size need',
#   'today want',
#   'touch come',
#   'understand website',
#   'unit_link plan',
#   'upload everybody',
#   'upload website',
#   'want information',
#   'want know',
#   'want unit_link',
#   'website information',
#   'website option',
#   'write mail',
#   'yeah_sure contact',
#   'yeah_sure mobile_number',
#   'yearly want'],
#  ['accord madam_uh',
#   'accord plan',
#   'assume inquire',
#   'band plan',
#   'benefit cover',
#   'benefit plan',
#   'benefit plus',
#   'benefit work',
#   'cash benefit',
#   'ciara phone',
#   'cover plan',
#   'critical illness',
#   'daily hospital',
#   'explain benefit',
#   'good accord',
#   'good morning',
#   'health_plan know',
#   'health_plan want',
#   'help want',
#   'hospital cash',
#   'illness benefit',
#   'information protected_health',
#   'inquire surgical',
#   'insurance help',
#   'know benefit',
#   'know know',
#   'know number',
#   'know option',
#   'know requirement',
#   'madam_uh accord',
#   'madam_uh assume',
#   'maybe refer',
#   'minute explain',
#   'morning welcome',
#   'number ciara',
#   'number information',
#   'option minute',
#   'option want',
#   'personal health_plan',
#   'phone number',
#   'plan band',
#   'plan daily',
#   'plan good',
#   'plan know',
#   'plan option',
#   'plan plan',
#   'plan sorry',
#   'plan true',
#   'plus critical',
#   'protect health_plan',
#   'protected_health plan',
#   'read personal',
#   'refer protected_health',
#   'requirement madam_uh',
#   'sorry protect',
#   'surgical benefit',
#   'true plan',
#   'want know',
#   'want read',
#   'welcome insurance',
#   'work maybe'],
#  ['afternoon customer',
#   'assure pension_plan',
#   'assure unit_link',
#   'care help',
#   'charge pension',
#   'charge tax_benefit',
#   'currently offer',
#   'customer care',
#   'earlier popular',
#   'flexible maturity',
#   'flexible_premium payment',
#   'frequency tax_benefit',
#   'fund zero_allocation',
#   'good afternoon',
#   'help today',
#   'high return',
#   'information want',
#   'link market',
#   'market want',
#   'maturity work',
#   'multiple fund',
#   'offer flexible_premium',
#   'offer pension_plan',
#   'online want',
#   'payment frequency',
#   'payment multiple',
#   'pension phone_number',
#   'pension super',
#   'pension_plan assure',
#   'pension_plan offer',
#   'pension_plan unit_link',
#   'people popular',
#   'phone_number currently',
#   'phone_number phone_number',
#   'plan assure',
#   'plan earlier',
#   'plan flexible_premium',
#   'plan suggest',
#   'plan unit_link',
#   'planet high',
#   'plus plan',
#   'popular plan',
#   'popular return',
#   'return link',
#   'return planet',
#   'suggest people',
#   'super plus',
#   'tax_benefit flexible',
#   'tax_benefit zero_allocation',
#   'thing online',
#   'think time',
#   'time information',
#   'today type',
#   'type pension',
#   'unit_link pension_plan',
#   'unit_link plan',
#   'want thing',
#   'want think',
#   'work plan',
#   'zero_allocation charge'],
#  ['activate online_portal',
#   'agent know',
#   'agent solve',
#   'agent talk',
#   'agent thing',
#   'azure pension_plan',
#   'benefit agent',
#   'benefit policy',
#   'care help',
#   'change agent',
#   'come unit',
#   'contact agent',
#   'currently enable',
#   'customer care',
#   'deal people_uh',
#   'enable minute',
#   'enable online',
#   'enable thing',
#   'enable want',
#   'graph noon',
#   'handle agent',
#   'hello history',
#   'help contact',
#   'help enable',
#   'help today',
#   'history life',
#   'know premium',
#   'know usually',
#   'life azure',
#   'life customer',
#   'link plan',
#   'minute premium',
#   'mommy want',
#   'need change',
#   'need enable',
#   'noon life',
#   'number minute',
#   'online need',
#   'online thing',
#   'online_portal activate',
#   'online_portal know',
#   'pension_plan come',
#   'pension_plan online_portal',
#   'people_uh deal',
#   'people_uh premium',
#   'plan currently',
#   'policy number',
#   'premium benefit',
#   'premium handle',
#   'premium help',
#   'premium yard',
#   'problem need',
#   'right mommy',
#   'solve problem',
#   'talk right',
#   'thing help',
#   'thing pension_plan',
#   'thing thing',
#   'thing want',
#   'today hello',
#   'unit link',
#   'usually people_uh',
#   'want enable',
#   'want know',
#   'want online',
#   'yard benefit'],
#  ['actually benefit',
#   'alright alright',
#   'alright history',
#   'apply online',
#   'bank share',
#   'benefit actually',
#   'benefit cross',
#   'benefit depend',
#   'benefit term_insurance',
#   'case death',
#   'company bank',
#   'company insurance_company',
#   'coverage term_insurance',
#   'cross thing',
#   'death insure',
#   'death_benefit company',
#   'death_benefit exactly',
#   'depend type',
#   'exactly insurance_company',
#   'financial coverage',
#   'goal policy',
#   'good morning',
#   'hello good',
#   'help want',
#   'history nice',
#   'holder specific',
#   'individual policy',
#   'insurance product',
#   'insurance_company apply',
#   'insurance_company goal',
#   'insurance_company offer',
#   'insure individual',
#   'life insurance',
#   'monthly visor',
#   'morning help',
#   'nice statement',
#   'offer financial',
#   'offer insurance_company',
#   'online apply',
#   'online possible',
#   'period case',
#   'policy benefit',
#   'policy company',
#   'policy holder',
#   'policy term',
#   'policy want',
#   'possible alright',
#   'premium benefit',
#   'product offer',
#   'quarterly razor',
#   'razor yearly',
#   'right premium',
#   'share right',
#   'specific time',
#   'term death_benefit',
#   'term_insurance life',
#   'term_insurance policy',
#   'thing death_benefit',
#   'time period',
#   'type policy',
#   'usually monthly',
#   'visor quarterly',
#   'want term_insurance',
#   'want usually',
#   'wise benefit',
#   'yearly wise'],
#  ['actually know',
#   'actually want',
#   'afternoon welcome',
#   'assume platinum',
#   'available rupee',
#   'burden monthly',
#   'depend different',
#   'depend plan',
#   'differ assume',
#   'difference difference',
#   'difference madam_uh',
#   'different premium',
#   'easy health',
#   'easy plan',
#   'exactly difference',
#   'fine think',
#   'frequency plan',
#   'gold silver',
#   'good afternoon',
#   'health insurance',
#   'help actually',
#   'high think',
#   'insurance help',
#   'insurance madam_uh',
#   'know look',
#   'know phone',
#   'know recommend',
#   'know regard',
#   'life insurance',
#   'look monthly',
#   'look option',
#   'madam_uh depend',
#   'madam_uh know',
#   'maximum payout',
#   'minimum premium',
#   'mobile number',
#   'monthly plan',
#   'monthly premium',
#   'monthly yearly',
#   'number easy',
#   'number mobile',
#   'option gold',
#   'payment frequency',
#   'payout available',
#   'perfect fine',
#   'phone number',
#   'plan burden',
#   'plan look',
#   'plan monthly',
#   'plan perfect',
#   'plan plan',
#   'plan premium',
#   'plan quarterly',
#   'platinum exactly',
#   'platinum high',
#   'platinum minimum',
#   'platinum platinum',
#   'premium differ',
#   'premium know',
#   'premium maximum',
#   'premium plan',
#   'premium premium',
#   'premium rupee',
#   'quarterly plan',
#   'quarterly yearly',
#   'recommend quarterly',
#   'recommend recommend',
#   'regard easy',
#   'rupee payment',
#   'silver platinum',
#   'think platinum',
#   'think premium',
#   'want know',
#   'welcome life',
#   'yearly actually',
#   'yearly depend'],
#  ['account sorry',
#   'afternoon life',
#   'agent term',
#   'apologize inconvenience',
#   'apply insurance',
#   'assist life',
#   'aware time',
#   'brochure assist',
#   'brochure require',
#   'care help',
#   'check toll_free',
#   'claim check',
#   'claim hour',
#   'claim insurance',
#   'claim request',
#   'claim response',
#   'customer care',
#   'good afternoon',
#   'happen apologize',
#   'heavy mention',
#   'help today',
#   'hour process',
#   'inconvenience verification',
#   'information present',
#   'insurance brochure',
#   'insurance reflect',
#   'insurance think',
#   'know claim',
#   'know happen',
#   'know policy_number',
#   'life customer',
#   'life good',
#   'mention thing',
#   'number insurance',
#   'number request',
#   'payment know',
#   'payment term',
#   'pension plus',
#   'plus policy',
#   'policy payment',
#   'policy_number agent',
#   'policy_number policy_number',
#   'present website',
#   'process heavy',
#   'purpose know',
#   'record claim',
#   'reflect account',
#   'request claim',
#   'request record',
#   'require sail',
#   'response know',
#   'right claim',
#   'sail sorry',
#   'send toll_free',
#   'sorry brochure',
#   'sorry right',
#   'term claim',
#   'term payment',
#   'thing aware',
#   'think send',
#   'time information',
#   'today pension',
#   'toll_free number',
#   'verification purpose',
#   'website apply'],
#  ['agent online',
#   'ahdfc life',
#   'assure significant',
#   'birth birth',
#   'birth jail',
#   'birth shell',
#   'chance link',
#   'claim policy',
#   'cover option',
#   'criterion minimum',
#   'easy policy',
#   'eligibility criterion',
#   'email policy',
#   'enable policyholder',
#   'exeter pillar',
#   'extra_life income_option',
#   'feature term_plan',
#   'frequency monthly',
#   'good interesting',
#   'half yearly',
#   'hello ahdfc',
#   'help term_plan',
#   'help want',
#   'history term_plan',
#   'income_option extra_life',
#   'income_option option',
#   'increase assure',
#   'increase birth',
#   'increase history',
#   'interesting option',
#   'jail measure',
#   'kevin help',
#   'kevin kevin',
#   'kind unit',
#   'know plus',
#   'life help',
#   'life marriage',
#   'life option',
#   'life stage',
#   'link purely',
#   'link stock',
#   'live option_extra',
#   'market kind',
#   'marriage birth',
#   'marriage measure',
#   'maximum year',
#   'measure increase',
#   'minimum year',
#   'month email',
#   'monthly quarterly',
#   'mouth month',
#   'online easy',
#   'option good',
#   'option income_option',
#   'option life',
#   'option live',
#   'option_extra life',
#   'payment frequency',
#   'pillar post',
#   'plan kevin',
#   'plus plan',
#   'policy chance',
#   'policy premium',
#   'policy term',
#   'policy want',
#   'policyholder increase',
#   'politic policy',
#   'post marriage',
#   'premium payment',
#   'protection feature',
#   'provide cover',
#   'purely term',
#   'quarterly half',
#   'shell exeter',
#   'significant stage',
#   'sort claim',
#   'stage life',
#   'stage protection',
#   'stock market',
#   'term policy',
#   'term year',
#   'term_plan eligibility',
#   'term_plan enable',
#   'term_plan provide',
#   'unit link',
#   'want agent',
#   'want know',
#   'year maximum',
#   'year politic',
#   'year sort',
#   'yearly mouth',
#   'yearly yearly'],
#  ['card debit',
#   'card online',
#   'credit card',
#   'cross date',
#   'date premium',
#   'debit card',
#   'free payment',
#   'future premium',
#   'hassle free',
#   'help moment',
#   'help purchase',
#   'issue future',
#   'issue net_banking',
#   'kindly register_online',
#   'know payment',
#   'know premium',
#   'mention policy_number',
#   'mention remark',
#   'moment register_online',
#   'net_banking credit',
#   'net_banking issue',
#   'net_banking mention',
#   'online wonderful',
#   'payment help',
#   'payment kindly',
#   'payment know',
#   'payment net_banking',
#   'payment payment',
#   'payment thing',
#   'plan want',
#   'policy_number policy_number',
#   'policy_number quarterly',
#   'premium issue',
#   'premium payment',
#   'premium plan',
#   'premium policy_number',
#   'purchase young',
#   'quarterly payment',
#   'register_online hassle',
#   'register_online time',
#   'remark mention',
#   'star super',
#   'super premium',
#   'thing net_banking',
#   'time cross',
#   'want know',
#   'welcome help',
#   'wonderful payment',
#   'young star'],
#  ['actually write',
#   'agent document',
#   'agent place',
#   'assist thing',
#   'atfc life',
#   'caller toll',
#   'card copy',
#   'collect document',
#   'collect place',
#   'complete agent',
#   'copy good',
#   'craig want',
#   'definitely form',
#   'document actually',
#   'document collect',
#   'document online',
#   'document require',
#   'document tomorrow',
#   'document write',
#   'fine know',
#   'form send',
#   'free number',
#   'good require',
#   'help craig',
#   'insurance work',
#   'know document',
#   'know submit',
#   'know time',
#   'know want',
#   'life caller',
#   'life help',
#   'mail state',
#   'number assist',
#   'online query',
#   'passport size',
#   'photograph card',
#   'pickup service',
#   'place representative',
#   'place soon',
#   'plan know',
#   'process complete',
#   'query life',
#   'register young',
#   'representative collect',
#   'request fine',
#   'require passport',
#   'require right',
#   'right definitely',
#   'send agent',
#   'send document',
#   'service document',
#   'size photograph',
#   'soon possible',
#   'star plan',
#   'state request',
#   'submit document',
#   'thing pickup',
#   'time process',
#   'toll free',
#   'tomorrow insurance',
#   'want know',
#   'want register',
#   'welcome atfc',
#   'work know',
#   'write mail',
#   'write send',
#   'young star'],
#  ['afternoon welcome',
#   'cancer care',
#   'care claim',
#   'check problem',
#   'claim lightly',
#   'claim process',
#   'claim week',
#   'close policy',
#   'crazy person',
#   'damn thing',
#   'dominate policy',
#   'ease claim',
#   'emily policy',
#   'escalate matter',
#   'good afternoon',
#   'help damn',
#   'help ease',
#   'help emily',
#   'help think',
#   'henceforth uh_ok',
#   'inconvenience madam_uh',
#   'insurance help',
#   'lightly sorry',
#   'look solve',
#   'madam_uh escalate',
#   'madam_uh wish',
#   'matter soon',
#   'matter supervisor',
#   'maybe help',
#   'number upset',
#   'offer help',
#   'past week',
#   'person cancer',
#   'plan offer',
#   'policy number',
#   'policy sorry',
#   'policy want',
#   'possible want',
#   'premium shut_policy',
#   'problem maybe',
#   'process time',
#   'relationship henceforth',
#   'renew premium',
#   'renew sorry',
#   'response term',
#   'shut_policy renew',
#   'shut_policy uh_ok',
#   'shut_policy want',
#   'solve matter',
#   'soon possible',
#   'sorry inconvenience',
#   'sorry plan',
#   'split want',
#   'supervisor look',
#   'term want',
#   'thing past',
#   'think crazy',
#   'think help',
#   'time shut_policy',
#   'uh_let check',
#   'uh_ok madam_uh',
#   'uh_ok uh_let',
#   'upset claim',
#   'want dominate',
#   'want relationship',
#   'want renew',
#   'want shut_policy',
#   'want split',
#   'week response',
#   'week think',
#   'welcome insurance',
#   'wish close'],
#  ['actually generally',
#   'actually premium',
#   'away process',
#   'change policy',
#   'confirmation wait',
#   'conversation welcome',
#   'convert policy',
#   'entire surely',
#   'evening help',
#   'generally monthly_wise',
#   'good evening',
#   'great convert',
#   'hello good',
#   'help actually',
#   'mobile_number confirmation',
#   'mobile_number policy_number',
#   'month want',
#   'monthly_wise great',
#   'monthly_wise quarterly',
#   'payment conversation',
#   'play monthly_wise',
#   'policy possible',
#   'policy quarterly',
#   'policy_number mobile_number',
#   'possible play',
#   'premium month',
#   'process wait',
#   'quarterly thing',
#   'quarterly yearly',
#   'right away',
#   'surely actually',
#   'thing policy_number',
#   'wait payment',
#   'wait right',
#   'want change',
#   'want entire',
#   'welcome nice',
#   'wise want',
#   'yearly wise'],
#  ['agent want',
#   'angel help',
#   'arrange callback',
#   'asians rhdfc',
#   'basically year',
#   'benefit similar',
#   'benefit sorry',
#   'benefit term_insurance',
#   'callback want',
#   'check contact',
#   'company policy',
#   'company service',
#   'condition company',
#   'contact agent',
#   'contact asians',
#   'contact policy',
#   'depend term',
#   'difference year_premium',
#   'discount premium',
#   'everybody discount',
#   'genuine perfect',
#   'hello angel',
#   'hello want',
#   'help hello',
#   'high year_premium',
#   'know premium',
#   'maintain everybody',
#   'offer discount',
#   'perfect depend',
#   'policy basically',
#   'policy check',
#   'policy maintain',
#   'policy premium',
#   'policy reach',
#   'policy willing',
#   'policy year_premium',
#   'premium benefit',
#   'premium policy',
#   'process thing',
#   'reach type',
#   'rhdfc contact',
#   'service genuine',
#   'similar contact',
#   'sorry company',
#   'term condition',
#   'term_insurance policy',
#   'thing policy',
#   'type policy',
#   'type term_insurance',
#   'want arrange',
#   'want know',
#   'want process',
#   'willing offer',
#   'year difference',
#   'year year',
#   'year_premium benefit',
#   'year_premium high',
#   'year_premium type'],
#  ['account sorry',
#   'apologize inconvenience',
#   'apply insurance',
#   'assist pleasant',
#   'aware information',
#   'brad pitt',
#   'brochure require',
#   'claim hour',
#   'claim insurance',
#   'claim request',
#   'claim response',
#   'claim toll_free',
#   'devillier nominee',
#   'fine assist',
#   'help young',
#   'hour process',
#   'inconvenience verification',
#   'information fine',
#   'information present',
#   'insurance brochure',
#   'insurance claim',
#   'insurance policy',
#   'insurance reflect',
#   'insurance send',
#   'know claim',
#   'know policy_number',
#   'mention thing',
#   'moment payment',
#   'nominee brad',
#   'number insurance',
#   'number request',
#   'payment know',
#   'payment term',
#   'pitt policy_number',
#   'policy payment',
#   'policy_number devillier',
#   'policy_number moment',
#   'present website',
#   'process mention',
#   'purpose know',
#   'record claim',
#   'reflect account',
#   'request claim',
#   'request record',
#   'require information',
#   'response apologize',
#   'right claim',
#   'send toll_free',
#   'sorry right',
#   'term claim',
#   'thing aware',
#   'toll_free number',
#   'verification purpose',
#   'website apply',
#   'young insurance'],
#  ['absolute assignment',
#   'alignment assign',
#   'alright want',
#   'assign policy',
#   'assigner know',
#   'assigning assign',
#   'assignment absolute',
#   'assignment conditional',
#   'assignment difference',
#   'assignment_process alright',
#   'assignment_process policyholder',
#   'assignment_process visit',
#   'assist require',
#   'attach policy',
#   'basically assignment_process',
#   'basically type',
#   'branch helpful',
#   'condition conditional',
#   'condition satisfied',
#   'conditional assignment',
#   'conditional condition',
#   'delight nice',
#   'difference know',
#   'help shasa',
#   'help want',
#   'helpful assist',
#   'inquire young',
#   'know alignment',
#   'know assignment_process',
#   'know condition',
#   'know phone_number',
#   'phone_number phone_number',
#   'phone_number want',
#   'plan help',
#   'policy assigning',
#   'policy basically',
#   'policy return',
#   'policyholder transfer',
#   'require delight',
#   'return revert',
#   'revert assigner',
#   'right attach',
#   'satisfied policy',
#   'shasa know',
#   'star plan',
#   'transfer right',
#   'type assignment',
#   'visit branch',
#   'want inquire',
#   'want know',
#   'welcome help',
#   'young star'],
#  ['apologize inconvenience',
#   'apply insurance',
#   'brochure require',
#   'care claim',
#   'claim hour',
#   'claim process',
#   'claim request',
#   'claim response',
#   'claim toll_free',
#   'complete read',
#   'customer care',
#   'health plan',
#   'help sorry',
#   'hour process',
#   'idea policy_number',
#   'inconvenience verification',
#   'information present',
#   'information think',
#   'insurance brochure',
#   'insurance help',
#   'insurance reflect',
#   'know policy_number',
#   'life insurance',
#   'mandel information',
#   'mann claim',
#   'mention thing',
#   'mistake sorry',
#   'number insurance',
#   'number request',
#   'okey mann',
#   'plan claim',
#   'policy_number idea',
#   'policy_number okey',
#   'present website',
#   'process mention',
#   'process reason',
#   'protect health',
#   'purpose know',
#   'read send',
#   'reason complete',
#   'record claim',
#   'reflect sorry',
#   'request claim',
#   'request record',
#   'request request',
#   'require information',
#   'response apologize',
#   'right claim',
#   'send toll_free',
#   'sorry customer',
#   'sorry protect',
#   'sorry right',
#   'sorry sorry',
#   'thing mandel',
#   'think mistake',
#   'toll_free number',
#   'verification purpose',
#   'website apply',
#   'welcome life'],
#  ['actually provide',
#   'afternoon life',
#   'annual available',
#   'annually processing',
#   'available bank',
#   'bank credit_card',
#   'basis flexibility',
#   'benefit equal',
#   'benefit provide',
#   'card net_banking',
#   'care help',
#   'carson net_banking',
#   'choose premium',
#   'credit_card choose',
#   'credit_card possible',
#   'customer care',
#   'david carson',
#   'death vest',
#   'debit card',
#   'different product',
#   'equal regular',
#   'feature mobile_number',
#   'feature plan',
#   'flexibility choose',
#   'flexibility investment',
#   'frequency quarterly_half',
#   'good afternoon',
#   'good service',
#   'hello life',
#   'help hello',
#   'horizon benefit',
#   'investment horizon',
#   'life basis',
#   'life customer',
#   'life pension',
#   'mobile_number feature',
#   'mobile_number mobile_number',
#   'net_banking option',
#   'net_banking provide',
#   'online service',
#   'option credit_card',
#   'payment frequency',
#   'pension super',
#   'personal pension',
#   'plan feature',
#   'plan flexibility',
#   'plan personal',
#   'plan plan',
#   'plan plus',
#   'plan service',
#   'plan single',
#   'plan special',
#   'plus plan',
#   'possible david',
#   'premium death',
#   'premium payment',
#   'premium quarterly_half',
#   'processing actually',
#   'product unit',
#   'provide debit',
#   'provide different',
#   'provide online',
#   'quarterly_half yearly',
#   'regular premium',
#   'service good',
#   'service plan',
#   'service service',
#   'single life',
#   'special benefit',
#   'super plan',
#   'unit plan',
#   'vest plan',
#   'yearly annual',
#   'yearly annually'],
#  ['apply term',
#   'approach happen',
#   'approve supervisor',
#   'authentication brother',
#   'away approach',
#   'brother mark',
#   'brother policy_number',
#   'brother time',
#   'check happen',
#   'check right',
#   'claim approve',
#   'claim term',
#   'evening life_insurance',
#   'ford policy_number',
#   'good evening',
#   'happen apply',
#   'happen claim',
#   'health issue',
#   'help claim',
#   'inconvenience authentication',
#   'insurance need',
#   'issue week',
#   'life_insurance help',
#   'life_insurance sell',
#   'mark ford',
#   'money happen',
#   'money sorry',
#   'need money',
#   'policy_number brother',
#   'policy_number wait',
#   'president week',
#   'process president',
#   'right away',
#   'second check',
#   'sell brother',
#   'sorry inconvenience',
#   'suffer health',
#   'supervisor suffer',
#   'term insurance',
#   'term life_insurance',
#   'time process',
#   'wait money',
#   'wait second',
#   'week check',
#   'week wait'],
#  ['activate error',
#   'activate morning',
#   'apologize inconvenience',
#   'assist life',
#   'beginning click',
#   'book invest',
#   'build phone',
#   'chasa policy',
#   'check unable',
#   'child insurance',
#   'click invest',
#   'click protect',
#   'complaint ensure',
#   'convey wrong',
#   'daniel devilliers',
#   'devilliers policy_number',
#   'early investment',
#   'effort result',
#   'ensure click',
#   'error update',
#   'fault twice',
#   'follow procedure',
#   'happen shall',
#   'hate click',
#   'help happen',
#   'help verification',
#   'inconvenience want',
#   'initiate early',
#   'initiate instead',
#   'instead follow',
#   'insurance message',
#   'invest build',
#   'invest chasa',
#   'invest child',
#   'invest initiate',
#   'invest policy',
#   'invest public',
#   'investment fault',
#   'investment look',
#   'issue want',
#   'know convey',
#   'know policy_number',
#   'later assist',
#   'life nice',
#   'live hate',
#   'look matter',
#   'louis help',
#   'matter later',
#   'message beginning',
#   'moment policy',
#   'morning know',
#   'phone book',
#   'plus activate',
#   'policy activate',
#   'policy click',
#   'policy reapply',
#   'policy_number check',
#   'policy_number daniel',
#   'policy_number right',
#   'pretty moment',
#   'procedure initiate',
#   'protect louis',
#   'protect plus',
#   'public invest',
#   'purpose know',
#   'raise complaint',
#   'raise issue',
#   'reapply click',
#   'result apologize',
#   'right pretty',
#   'shall help',
#   'time effort',
#   'twice waste',
#   'unable policy_number',
#   'update raise',
#   'verification purpose',
#   'want invest',
#   'want investment',
#   'want raise',
#   'waste time',
#   'welcome live',
#   'wrong want'],
#  ['absolute_assignment benefit',
#   'absolute_assignment conditional_assignment',
#   'actually payment',
#   'assign policy',
#   'assignee assign',
#   'assignee circumstance',
#   'assigner know',
#   'assignment absolute_assignment',
#   'assignment assign',
#   'assignment process',
#   'assist specifically',
#   'attach policy',
#   'available monthly',
#   'available thousand',
#   'benefit policy',
#   'circumstance conditional_assignment',
#   'click investment',
#   'condition satisfy',
#   'conditional_assignment absolute_assignment',
#   'conditional_assignment condition',
#   'enroll actually',
#   'enroll standing',
#   'help assignment',
#   'help phone_number',
#   'investment help',
#   'know assignment',
#   'know click',
#   'know type',
#   'life branch',
#   'male walk',
#   'monthly quarterly',
#   'online enroll',
#   'payment online',
#   'payment_plan available',
#   'phone_number assist',
#   'phone_number phone_number',
#   'policy assignee',
#   'policy help',
#   'policy revert',
#   'policy type',
#   'policyholder transfer',
#   'process policyholder',
#   'quarterly yearly',
#   'revert assigner',
#   'right attach',
#   'satisfy policy',
#   'specifically want',
#   'standing male',
#   'thousand enroll',
#   'transfer right',
#   'type assignment',
#   'type payment_plan',
#   'walk life',
#   'want know',
#   'yearly payment_plan'],
#  ['afternoon help',
#   'alright pleasant',
#   'angel policy',
#   'annually online',
#   'answer insurance',
#   'card debit_card',
#   'credit card',
#   'cross date',
#   'date premium',
#   'debit_card debit_card',
#   'debit_card wonderful',
#   'enter policy_number',
#   'forget month',
#   'free payment',
#   'future premium',
#   'good afternoon',
#   'good head',
#   'guinea monthly',
#   'hassle free',
#   'hawaii good',
#   'head purchase',
#   'help hawaii',
#   'insurance want',
#   'issue future',
#   'issue policy',
#   'kindly register_online',
#   'know premium',
#   'memorie register_online',
#   'mention remark',
#   'mobile uh_pay',
#   'month guinea',
#   'monthly online',
#   'monthly quarterly',
#   'net_banking credit',
#   'net_banking enter',
#   'net_banking issue',
#   'net_banking mention',
#   'online alright',
#   'online monthly',
#   'payment kindly',
#   'payment net_banking',
#   'payment thing',
#   'policy memorie',
#   'policy premium',
#   'policy_number angel',
#   'policy_number space',
#   'premium issue',
#   'premium net_banking',
#   'premium payment',
#   'premium policy_number',
#   'purchase answer',
#   'quarterly annually',
#   'question work',
#   'register_online hassle',
#   'register_online time',
#   'remark mobile',
#   'space question',
#   'stress forget',
#   'thing uh_pay',
#   'time cross',
#   'uh_pay net_banking',
#   'want know',
#   'wonderful payment',
#   'work stress'],
#  ['actually interested',
#   'ahead mobile_number',
#   'application process',
#   'august thank_sir',
#   'birth august',
#   'birth date',
#   'date birth',
#   'decision wait',
#   'easy monthly',
#   'entire thing',
#   'enzo ferrari',
#   'ferrari mobile_number',
#   'great decision',
#   'help actually',
#   'help register',
#   'hour time',
#   'insurance plan',
#   'interested project',
#   'interesting option',
#   'minute process',
#   'mobile_number enzo',
#   'mobile_number need',
#   'month monthly',
#   'monthly monthly_plan',
#   'monthly payment',
#   'monthly_plan interesting',
#   'monthly_plan thank_sir',
#   'mood want',
#   'need ahead',
#   'need date',
#   'notification hour',
#   'option great',
#   'option project',
#   'payment mood',
#   'payment quarterly',
#   'plan help',
#   'plan payment',
#   'plus plan',
#   'plus term',
#   'possible processing',
#   'process notification',
#   'process sorry',
#   'processing need',
#   'project plus',
#   'quarterly yearly',
#   'register possible',
#   'sorry application',
#   'teorie option',
#   'term insurance',
#   'thank_sir monthly_plan',
#   'thank_sir teorie',
#   'time entire',
#   'wait minute',
#   'want easy',
#   'welcome help',
#   'yearly month'],
#  ['account statement',
#   'check moment',
#   'check problem',
#   'check quickly',
#   'confirmation mail',
#   'continuously irritate',
#   'couple regard',
#   'directly escalate',
#   'email account',
#   'escalate issue',
#   'escalate supervisor',
#   'escalate talk',
#   'handle thing',
#   'hello life',
#   'help today',
#   'hour reflect',
#   'irritate message',
#   'issue check',
#   'issue confirmation',
#   'know policy_number',
#   'know reflect',
#   'life help',
#   'mail know',
#   'message need',
#   'mobile number',
#   'moment check',
#   'moment time',
#   'need check',
#   'need escalate',
#   'number moment',
#   'number policy_number',
#   'payment continuously',
#   'payment reflect',
#   'payment sorry',
#   'phone number',
#   'policy_number mobile',
#   'policy_number phone',
#   'premium payment',
#   'problem escalate',
#   'quickly think',
#   'receipt payment',
#   'record want',
#   'reflect hour',
#   'reflect payment',
#   'reflect record',
#   'reflect sorry',
#   'regard premium',
#   'ridiculous reflect',
#   'send email',
#   'senior need',
#   'sorry directly',
#   'sorry issue',
#   'statement receipt',
#   'supervisor handle',
#   'talk senior',
#   'talk want',
#   'thing right',
#   'think know',
#   'time ridiculous',
#   'today couple',
#   'want send',
#   'want talk'],
#  ['afternoon life',
#   'agent touch',
#   'angel mobile_number',
#   'annually half',
#   'assure invest',
#   'avail policy',
#   'benefit benefit',
#   'benefit plan',
#   'benefit saving',
#   'benefit survival',
#   'bonus death',
#   'briefly yeah_sure',
#   'care help',
#   'choose premium',
#   'cool policy',
#   'customer care',
#   'dayton payment',
#   'death benefit',
#   'explain briefly',
#   'follow assure',
#   'good afternoon',
#   'half yearly',
#   'help think',
#   'help today',
#   'high follow',
#   'invest plus',
#   'know need',
#   'know retirement_plan',
#   'life customer',
#   'mobile_number angel',
#   'mobile_number pokémon',
#   'monthly choose',
#   'multiple benefit',
#   'need yeah_sure',
#   'online agent',
#   'option play',
#   'payment premium',
#   'plan cool',
#   'plan plus',
#   'plan vest',
#   'play plan',
#   'play premium',
#   'plus option',
#   'plus secure',
#   'pokémon retirement_plan',
#   'policy avail',
#   'policy online',
#   'policy right',
#   'policy term',
#   'premium annually',
#   'premium policy',
#   'premium want',
#   'quarterly monthly',
#   'receive high',
#   'retirement_plan explain',
#   'retirement_plan multiple',
#   'right think',
#   'saving plan',
#   'secure bonus',
#   'survival till',
#   'term receive',
#   'think time',
#   'till weste',
#   'time know',
#   'today want',
#   'touch want',
#   'vest benefit',
#   'want know',
#   'want play',
#   'want policy',
#   'weste dayton',
#   'yeah_sure help',
#   'yeah_sure mobile_number',
#   'yearly quarterly'],
#  ['actually android',
#   'address sorry',
#   'agent address',
#   'agent time',
#   'ahead right',
#   'android policy',
#   'annual payment',
#   'card quick',
#   'click invest_plan',
#   'collect document',
#   'come tomorrow',
#   'copy card',
#   'copy health',
#   'document insurance_policy',
#   'document know',
#   'document require',
#   'document work',
#   'doubt need',
#   'enrol purpose',
#   'enroll ahead',
#   'enroll click',
#   'health test',
#   'help phone',
#   'help want',
#   'insurance_policy copy',
#   'insurance_policy kick',
#   'invest_plan help',
#   'invest_plan windsor',
#   'kick premium',
#   'know annual',
#   'know document',
#   'know mention',
#   'mention document',
#   'need passport',
#   'need payment',
#   'need submit',
#   'number enroll',
#   'number number',
#   'online procedure',
#   'online send',
#   'passport size',
#   'payment send',
#   'payment sleep',
#   'phone number',
#   'photograph document',
#   'policy upload',
#   'premium start',
#   'procedure enrol',
#   'purpose need',
#   'quick doubt',
#   'require need',
#   'right online',
#   'send agent',
#   'size photograph',
#   'sleep know',
#   'slip click',
#   'sorry come',
#   'start know',
#   'submit slip',
#   'test copy',
#   'time send',
#   'tomorrow collect',
#   'upload online',
#   'want enroll',
#   'windsor actually',
#   'work insurance_policy'],
#  ['actually happen',
#   'actually health',
#   'away process',
#   'cash notification',
#   'check actually',
#   'check eligible',
#   'claim daily',
#   'claim hour',
#   'claim right',
#   'claim think',
#   'daily hospital',
#   'easy health',
#   'eligible claim',
#   'eligible know',
#   'error want',
#   'good_service provide',
#   'happen need',
#   'health easy',
#   'health plan',
#   'help today',
#   'hospital cash',
#   'hour process',
#   'know know',
#   'know policy_number',
#   'know reason',
#   'minute check',
#   'money good_service',
#   'need policy_number',
#   'notification eligible',
#   'number procedure',
#   'plan week',
#   'policy_number provide',
#   'policy_number think',
#   'policy_number wait',
#   'problem error',
#   'procedure service',
#   'process claim',
#   'process money',
#   'provide policy_number',
#   'provide sorry',
#   'reason sorry',
#   'registration number',
#   'right away',
#   'service good_service',
#   'sorry check',
#   'sorry know',
#   'summer registration',
#   'think problem',
#   'think summer',
#   'today actually',
#   'wait minute',
#   'want process',
#   'week claim',
#   'welcome help'],
#  ['account sorry',
#   'bank account',
#   'confirmation message',
#   'deduct bank',
#   'good morning',
#   'help premium',
#   'help verification',
#   'hour help',
#   'hour payment',
#   'ignore message',
#   'issue usually',
#   'january possible',
#   'kindly ignore',
#   'kindly know',
#   'kindly moment',
#   'know policy_number',
#   'know time',
#   'life help',
#   'message receive',
#   'message regard',
#   'moment young',
#   'month january',
#   'morning life',
#   'morning yesterday',
#   'payment hour',
#   'payment morning',
#   'payment spend',
#   'payment update',
#   'plan premium',
#   'policy_number kindly',
#   'policy_number policy_number',
#   'possible yesterday',
#   'premium month',
#   'premium time',
#   'purpose know',
#   'purpose receive',
#   'receive confirmation',
#   'receive today',
#   'regard payment',
#   'sorry kindly',
#   'spend help',
#   'star turn',
#   'state payment',
#   'time payment',
#   'time state',
#   'today want',
#   'turn plan',
#   'update kindly',
#   'usually hour',
#   'verification purpose',
#   'want purpose',
#   'yesterday deduct',
#   'yesterday issue',
#   'young star'],
#  ['actually unit',
#   'afternoon life',
#   'agent installment',
#   'alright fine',
#   'alright premium',
#   'care help',
#   'change quarterly',
#   'change think',
#   'change want',
#   'change year',
#   'customer care',
#   'fine change',
#   'good afternoon',
#   'half_yearly change',
#   'half_yearly payment',
#   'help today',
#   'initiate initiate',
#   'initiate need',
#   'installment quarterly',
#   'instead half_yearly',
#   'know premium',
#   'life customer',
#   'link plan',
#   'payment change',
#   'payment half_yearly',
#   'payment possible',
#   'payment premium',
#   'plan know',
#   'policy_number half_yearly',
#   'policy_number shut',
#   'possible change',
#   'premium payment',
#   'premium policy_number',
#   'premium quarterly',
#   'quarterly alright',
#   'quarterly instead',
#   'quarterly premium',
#   'shut policy_number',
#   'think agent',
#   'today actually',
#   'unit link',
#   'want initiate',
#   'year payment'],
#  ['actually life_term',
#   'actually term_plan',
#   'affordability nominee',
#   'agent need',
#   'annualize manually',
#   'annualize premium',
#   'area facilitate',
#   'assure minimum',
#   'avail policy',
#   'benefit premium_pay',
#   'cost simple',
#   'date debt',
#   'death insure',
#   'debt benefit',
#   'entry year',
#   'event death',
#   'facilitate inclusion',
#   'family event',
#   'frequency monthly',
#   'graph want',
#   'hello help',
#   'help graph',
#   'help plan',
#   'hire measure',
#   'history term',
#   'inclusion rural',
#   'income entry',
#   'information plan',
#   'insurance actually',
#   'insurance plan',
#   'insure premium',
#   'kevin help',
#   'know kevin',
#   'know term_plan',
#   'life_term plan',
#   'lump family',
#   'mail agent',
#   'maintain insurance',
#   'manually mount',
#   'maximum payment',
#   'measure time',
#   'minimum maximum',
#   'month avail',
#   'monthly quarterly',
#   'mount premium',
#   'need nice',
#   'nominee receive',
#   'online mail',
#   'payment frequency',
#   'percentage total',
#   'plan actually',
#   'plan know',
#   'plan rural',
#   'plan term_plan',
#   'policy online',
#   'policy_term policy_term',
#   'policy_term year',
#   'population maintain',
#   'premium month',
#   'premium percentage',
#   'premium term_plan',
#   'premium_pay date',
#   'premium_pay income',
#   'provide lump',
#   'quarterly semi',
#   'receive hire',
#   'rural area',
#   'rural population',
#   'semi annualize',
#   'sham assure',
#   'short affordability',
#   'simple understand',
#   'term insurance',
#   'term_plan cost',
#   'term_plan information',
#   'term_plan provide',
#   'term_plan short',
#   'time annualize',
#   'total premium_pay',
#   'understand history',
#   'want know',
#   'year policy_term',
#   'year sham'],
#  ['account actually',
#   'actually register',
#   'applicable service',
#   'assist maybe',
#   'charge applicable',
#   'check fund',
#   'check phone',
#   'child insurance',
#   'continuous update',
#   'david policy_number',
#   'ease registration_process',
#   'easy time',
#   'estimate facility',
#   'facility registration_process',
#   'fine register',
#   'fund value',
#   'help want',
#   'insurance registration',
#   'insurance verification',
#   'jessa assist',
#   'know check',
#   'know policy_number',
#   'life pleasant',
#   'link policy',
#   'maybe ease',
#   'note unit',
#   'online register',
#   'phone value',
#   'policy child',
#   'policy policy',
#   'policy summary',
#   'policy thing',
#   'policy_number david',
#   'policy_number right',
#   'policy_number second',
#   'post continuous',
#   'procedure easy',
#   'provider jessa',
#   'purpose know',
#   'register estimate',
#   'register online',
#   'register service',
#   'registration procedure',
#   'registration_process insurance',
#   'registration_process life',
#   'registration_process post',
#   'right note',
#   'second check',
#   'section account',
#   'service provider',
#   'service type',
#   'space policy_number',
#   'summary section',
#   'thing charge',
#   'time registration_process',
#   'type space',
#   'unit link',
#   'update fine',
#   'value policy',
#   'verification purpose',
#   'want know'],
#  ['account register',
#   'ahdfc life',
#   'check fund',
#   'continuous update',
#   'easy time',
#   'facility registration_process',
#   'fund value',
#   'hello ahdfc',
#   'help today',
#   'insurance registration',
#   'know policy_number',
#   'know value',
#   'life help',
#   'online register',
#   'plan policy',
#   'plus plan',
#   'policy policy',
#   'policy register',
#   'policy resistor',
#   'policy summary',
#   'policy_number check',
#   'policy_number policy_number',
#   'policy_number send',
#   'post continuous',
#   'procedure easy',
#   'protect plus',
#   'purpose know',
#   'register facility',
#   'register online',
#   'register verification',
#   'registration procedure',
#   'registration_process insurance',
#   'registration_process post',
#   'resistor policy',
#   'section account',
#   'service type',
#   'space policy_number',
#   'summary section',
#   'time registration_process',
#   'today want',
#   'type space',
#   'update service',
#   'value policy',
#   'value protect',
#   'verification purpose',
#   'want know'],
#  ['actually premium',
#   'assist nice',
#   'confirmation message',
#   'confused right',
#   'help premium',
#   'hour payment',
#   'ignore message',
#   'january possible',
#   'know plan',
#   'little confused',
#   'mean know',
#   'message receive',
#   'message regard',
#   'month january',
#   'payment assist',
#   'payment pende',
#   'payment problem',
#   'payment update',
#   'pende actually',
#   'pende mean',
#   'plan little',
#   'plan policy_number',
#   'plan sms_state',
#   'plan youngster',
#   'policy_number plan',
#   'policy_number sorry',
#   'possible yesterday',
#   'premium month',
#   'premium policy_number',
#   'premium time',
#   'problem hour',
#   'purpose receive',
#   'receive confirmation',
#   'receive today',
#   'regard payment',
#   'right want',
#   'right youngstar',
#   'silly purpose',
#   'sms_state payment',
#   'sorry state',
#   'star plan',
#   'state young',
#   'super premium',
#   'time payment',
#   'time sms_state',
#   'today right',
#   'update ignore',
#   'want silly',
#   'welcome help',
#   'yesterday time',
#   'young star',
#   'youngstar plan',
#   'youngster plan',
#   'youngster super'],
#  ['actually hour',
#   'confirmation message',
#   'good morning',
#   'help life',
#   'help premium',
#   'help verification',
#   'hour payment',
#   'hour time',
#   'ignore message',
#   'issue actually',
#   'january possible',
#   'kindly ignore',
#   'kindly know',
#   'kindly moment',
#   'know policy_number',
#   'know time',
#   'life help',
#   'life pleasant',
#   'message receive',
#   'message regard',
#   'moment premium',
#   'month january',
#   'morning life',
#   'payment hour',
#   'payment issue',
#   'payment pende',
#   'payment update',
#   'pende help',
#   'policy_number kindly',
#   'policy_number samson',
#   'possible yesterday',
#   'premium month',
#   'premium time',
#   'purpose know',
#   'purpose receive',
#   'receive confirmation',
#   'receive today',
#   'regard payment',
#   'right want',
#   'samson policy_number',
#   'state payment',
#   'time help',
#   'time payment',
#   'time state',
#   'today right',
#   'update kindly',
#   'verification purpose',
#   'want purpose',
#   'yesterday kindly'],
#  ['agent come',
#   'agent stupid',
#   'assume policy',
#   'certificate forge_signature',
#   'charge penalty',
#   'code send',
#   'come place',
#   'commission forge_signature',
#   'complaint life',
#   'customer_care help',
#   'customer_care time',
#   'email charge',
#   'father certificate',
#   'father policy',
#   'forge_signature assume',
#   'forge_signature message',
#   'good morning',
#   'happen know',
#   'hear response',
#   'help supervisor',
#   'help today',
#   'home know',
#   'issue policy',
#   'know agent',
#   'know father',
#   'know policy',
#   'life customer_care',
#   'life rate',
#   'message premium',
#   'message send',
#   'mister miyagi',
#   'mister nominee',
#   'miyagi true',
#   'morning life',
#   'need write',
#   'nominee wrong',
#   'notification understand',
#   'number request',
#   'payment notification',
#   'penalty sorry',
#   'physically home',
#   'place pokémon',
#   'place sell',
#   'pokémon need',
#   'policy issue',
#   'policy know',
#   'policy mister',
#   'policy number',
#   'policy payment',
#   'policy place',
#   'policy stupid',
#   'policy want',
#   'premium message',
#   'premium want',
#   'present physically',
#   'rate customer_care',
#   'request policy',
#   'response ridiculous',
#   'ridiculous code',
#   'sell policy',
#   'send premium',
#   'send threaten',
#   'sorry help',
#   'stupid agent',
#   'stupid commission',
#   'threaten email',
#   'time hear',
#   'today father',
#   'true mister',
#   'understand happen',
#   'want policy',
#   'want present',
#   'write complaint',
#   'wrong policy'],
#  ['account upload',
#   'agency care',
#   'agent customer',
#   'agent online',
#   'avail plan',
#   'available offer',
#   'card card',
#   'card scan',
#   'care know',
#   'care want',
#   'check check',
#   'check help',
#   'condition know',
#   'confirmation mail',
#   'contact agency',
#   'customer care',
#   'document confirmation',
#   'document need',
#   'guide verification',
#   'hello help',
#   'help term',
#   'help want',
#   'kevin mobile_number',
#   'know mobile_number',
#   'know plan',
#   'know procedure',
#   'later agent',
#   'mail know',
#   'mobile_number check',
#   'mobile_number kevin',
#   'need avail',
#   'need submit',
#   'need write',
#   'offer document',
#   'online later',
#   'online registration',
#   'option account',
#   'plan guide',
#   'plan sorry',
#   'plan want',
#   'portal resist',
#   'premium need',
#   'procedure premium',
#   'registration submit',
#   'resist option',
#   'scan upload',
#   'sorry want',
#   'submit available',
#   'submit need',
#   'term condition',
#   'term plan',
#   'upload document',
#   'upload portal',
#   'verification confirmation',
#   'want agent',
#   'want contact',
#   'want online',
#   'want term',
#   'write card',
#   'write need'],
#  ['afternoon kevin',
#   'agent possible',
#   'angry phone_number',
#   'avail plan',
#   'contact online',
#   'county register',
#   'document query',
#   'free_number contact',
#   'good afternoon',
#   'hello help',
#   'help good',
#   'help phone_number',
#   'kevin help',
#   'kevin online',
#   'kevin yesterday',
#   'know want',
#   'live toll',
#   'need angry',
#   'online pension_plus',
#   'online possible',
#   'online query',
#   'online send',
#   'online term',
#   'online want',
#   'pension_plus plan',
#   'phone_number kevin',
#   'phone_number record',
#   'plan register',
#   'plan term_plan',
#   'plan want',
#   'plus_plan free_number',
#   'possible online',
#   'possible procedure',
#   'premium write',
#   'procedure online',
#   'query live',
#   'query premium',
#   'record need',
#   'regard pension_plus',
#   'register website',
#   'register yeah_sure',
#   'resistor submit',
#   'right term_plan',
#   'send agent',
#   'submit document',
#   'term plus_plan',
#   'term_plan county',
#   'term_plan right',
#   'toll free_number',
#   'want avail',
#   'want know',
#   'want online',
#   'want yeah_sure',
#   'website resistor',
#   'write online',
#   'yeah_sure kevin',
#   'yeah_sure want',
#   'yesterday regard'],
#  ['afternoon help',
#   'away wait',
#   'check know',
#   'check reflect',
#   'check right',
#   'check time',
#   'dance think',
#   'dumb policy',
#   'entire notification',
#   'entire reflect',
#   'expire entire',
#   'fine madam_uh',
#   'good afternoon',
#   'happen problem',
#   'happen right',
#   'height dumb',
#   'hello good',
#   'help height',
#   'inconvenience check',
#   'inconvenience policy_number',
#   'issue sorry',
#   'know happen',
#   'know sorry',
#   'madam_uh entire',
#   'madam_uh query',
#   'mean proper',
#   'monitoring check',
#   'monitoring monitoring',
#   'negligent mean',
#   'notification fine',
#   'notification know',
#   'policy year',
#   'policy_number check',
#   'problem issue',
#   'process sorry',
#   'proper process',
#   'query dance',
#   'reflect monitoring',
#   'reflect notification',
#   'right away',
#   'right policy_number',
#   'right wait',
#   'second wait',
#   'sorry happen',
#   'sorry inconvenience',
#   'sorry negligent',
#   'sorry right',
#   'think great',
#   'time sorry',
#   'wait check',
#   'wait madam_uh',
#   'wait second',
#   'year expire'],
#  ['advert start',
#   'alright alright',
#   'alright service',
#   'case query',
#   'catch free_number',
#   'college toll_free',
#   'contact online',
#   'contact possibility',
#   'customer_service desk',
#   'desk right',
#   'desk separate',
#   'difference nail',
#   'document query',
#   'edit difference',
#   'edward college',
#   'email alright',
#   'email send',
#   'exactly contact',
#   'exactly write',
#   'farm feeling',
#   'feeling toll_free',
#   'free_number repeat',
#   'hello help',
#   'help high',
#   'high want',
#   'insurance reach',
#   'know online_term',
#   'mail service',
#   'male service',
#   'nail write',
#   'number contact',
#   'number policy',
#   'number time',
#   'number write',
#   'online advert',
#   'online query',
#   'online_term plan',
#   'payment write',
#   'plan farm',
#   'plan relate',
#   'policy insurance',
#   'possibility case',
#   'premium payment',
#   'query edward',
#   'query email',
#   'query exactly',
#   'query premium',
#   'query relate',
#   'reach customer_service',
#   'redhdfclife sorry',
#   'relate online_term',
#   'relate query',
#   'repeat exactly',
#   'right male',
#   'send write',
#   'separate email',
#   'service edit',
# ...
#   'email stuff',
#   'emily mobile_number',
#   'form registration',
#   'good morning',
#   'government proof',
#   'help form',
#   'help okie',
#   'help want',
#   'information help',
#   'information provide',
#   'insurance help',
#   'know mobile_number',
#   'know register',
#   'mobile_number emily',
#   'mobile_number information',
#   'mobile_number want',
#   'morning welcome',
#   'need mobile_number',
#   'need provide',
#   'number child',
#   'okie know',
#   'option send',
#   'plan help',
#   'proof want',
#   'provide card',
#   'provide information',
#   'provide relevant',
#   'register cancer',
#   'register need',
#   'registration alright',
#   'relevant door',
#   'require actually',
#   'send agent',
#   'send send',
#   'start need',
#   'stuff appointment',
#   'thing require',
#   'time email',
#   'time time',
#   'want know',
#   'want need',
#   'want register',
#   'want want',
#   'welcome insurance'],
#  ['afternoon welcome',
#   'agent come',
#   'black morning',
#   'card number',
#   'collect document',
#   'come collect',
#   'come know',
#   'cool think',
#   'document help',
#   'document place',
#   'easy_health insurance',
#   'endure enrolling',
#   'enroll easy_health',
#   'enroll ok_thank',
#   'enrolling plan',
#   'gold want',
#   'good afternoon',
#   'good cool',
#   'help endure',
#   'help ok_thank',
#   'help want',
#   'information help',
#   'insurance help',
#   'insurance kind',
#   'insurance plan',
#   'interested think',
#   'kind panel',
#   'know number',
#   'know plan',
#   'know skype',
#   'look easy_health',
#   'meeting agent',
#   'mobile number',
#   'morning quick',
#   'number card',
#   'number come',
#   'number know',
#   'ok_thank good',
#   'ok_thank personal',
#   'panel look',
#   'personal information',
#   'place meeting',
#   'plan silver',
#   'plan start',
#   'plan website',
#   'platinum gold',
#   'question come',
#   'quick question',
#   'read want',
#   'silver platinum',
#   'skype mobile',
#   'start know',
#   'think read',
#   'want black',
#   'want enroll',
#   'website interested',
#   'welcome insurance'],
#  ['actually policy',
#   'angel policy_number',
#   'care help',
#   'check extremely_sorry',
#   'come know',
#   'come regularly',
#   'complaint ratehdfclife',
#   'complete grace',
#   'contact suggest',
#   'customer care',
#   'escalate thing',
#   'extremely_sorry policy_number',
#   'extremely_sorry screen',
#   'frustrating know',
#   'grace period',
#   'help today',
#   'know check',
#   'know time',
#   'life customer',
#   'link plan',
#   'mail supervisor',
#   'maybe reminder',
#   'message policy',
#   'moment screen',
#   'month play',
#   'need escalate',
#   'need need',
#   'need submit',
#   'past month',
#   'payment past',
#   'payment send',
#   'period time',
#   'plan message',
#   'play think',
#   'pokémon moment',
#   'policy complete',
#   'policy payment',
#   'policy unit',
#   'policy_number pokémon',
#   'policy_number proceed',
#   'problem contact',
#   'proceed angel',
#   'proof complaint',
#   'proof extremely_sorry',
#   'proof payment',
#   'proofs need',
#   'ratehdfclife need',
#   'regularly come',
#   'reminder come',
#   'screen policy',
#   'screen proof',
#   'send proof',
#   'submit proof',
#   'suggest maybe',
#   'thing write',
#   'think proofs',
#   'time frustrating',
#   'time problem',
#   'today actually',
#   'unit link',
#   'write mail'],
#  ['account coin',
#   'activity claim',
#   'afternoon welcome',
#   'apply claim',
#   'authority revoke',
#   'cancer care',
#   'care processing',
#   'case apply',
#   'case issue',
#   'check claim',
#   'claim activity',
#   'claim case',
#   'claim claim',
#   'claim delete',
#   'claim policy',
#   'claim service',
#   'claim thing',
#   'coin service',
#   'compromise sorry_man',
#   'court wear',
#   'delete matter',
#   'drag court',
#   'escalate matter',
#   'good afternoon',
#   'good service',
#   'happen escalate',
#   'hello notification',
#   'help hello',
#   'insurance help',
#   'issue drag',
#   'justin check',
#   'life insurance',
#   'look policy',
#   'matter supervise',
#   'matter supervisor',
#   'notification service',
#   'number justin',
#   'people service',
#   'policy number',
#   'policy sorry_man',
#   'processing account',
#   'revoke claim',
#   'server people',
#   'service claim',
#   'service good',
#   'service look',
#   'service server',
#   'sorry_man case',
#   'sorry_man happen',
#   'supervisor authority',
#   'thing cancer',
#   'wear compromise',
#   'welcome life'],
#  ['action bear',
#   'actually pension',
#   'afternoon life',
#   'aged term',
#   'agent policy',
#   'agent procedure',
#   'bear people',
#   'claim agent',
#   'contact lose',
#   'face problem',
#   'file claim',
#   'follow face',
#   'good afternoon',
#   'handle position',
#   'help need',
#   'help today',
#   'inconvenience know',
#   'know policy',
#   'know sorry',
#   'know transfer',
#   'legal action',
#   'life help',
#   'little contact',
#   'lose know',
#   'money wide',
#   'month money',
#   'month single',
#   'need touch',
#   'number aged',
#   'pension plus',
#   'people sorry',
#   'plan term',
#   'plus plan',
#   'policy little',
#   'policy number',
#   'position right',
#   'problem actually',
#   'problem send',
#   'procedure follow',
#   'process think',
#   'right time',
#   'rupee wrong',
#   'send month',
#   'single rupee',
#   'sorry inconvenience',
#   'sorry transfer',
#   'supervisor handle',
#   'supervisor month',
#   'supervisor time',
#   'term file',
#   'term process',
#   'think help',
#   'time benefit',
#   'time time',
#   'time transfer',
#   'today face',
#   'touch agent',
#   'transfer supervisor',
#   'wide legal',
#   'wrong know'],
#  ['check wait',
#   'circle know',
#   'confirmation message',
#   'hello help',
#   'help message',
#   'help premium',
#   'help verification',
#   'hour payment',
#   'hour short',
#   'ignore message',
#   'issue site',
#   'january possible',
#   'kevin policy_number',
#   'kindly ignore',
#   'kindly moment',
#   'kindly time',
#   'know kindly',
#   'know policy_number',
#   'message receive',
#   'message regard',
#   'message right',
#   'moment check',
#   'month january',
#   'morning issue',
#   'payment hour',
#   'payment morning',
#   'payment payment',
#   'payment shore',
#   'payment update',
#   'policy_number kevin',
#   'policy_number kindly',
#   'possible premium',
#   'premier spending',
#   'premium month',
#   'premium time',
#   'premium yesterday',
#   'purpose know',
#   'purpose receive',
#   'receive confirmation',
#   'receive today',
#   'regard payment',
#   'right hour',
#   'shore help',
#   'short angry',
#   'site hour',
#   'spending help',
#   'state premier',
#   'time payment',
#   'time state',
#   'today want',
#   'update kindly',
#   'verification purpose',
#   'wait premium',
#   'want purpose',
#   'yesterday circle'],
#  ['action lose',
#   'afternoon life',
#   'agent mention',
#   'care help',
#   'come know',
#   'complain complaint',
#   'complaint website',
#   'complete policy_number',
#   'corpus know',
#   'customer care',
#   'customer good',
#   'fine second',
#   'good afternoon',
#   'good luck',
#   'guide mention',
#   'half customer',
#   'happen lose',
#   'help agent',
#   'help complete',
#   'help help',
#   'help today',
#   'invest lacs',
#   'kindly help',
#   'know know',
#   'know refund',
#   'know withdraw',
#   'lack rupee',
#   'lacs year',
#   'legal action',
#   'life customer',
#   'lose half',
#   'lose lack',
#   'mean want',
#   'mention legal',
#   'mention ridiculous',
#   'mention think',
#   'miss guide',
#   'money reinvest',
#   'month come',
#   'month year',
#   'need policy_number',
#   'plan month',
#   'policy_number need',
#   'policy_number require',
#   'possible resolve',
#   'refund money',
#   'refuse complain',
#   'reinvest refuse',
#   'require fine',
#   'resolve think',
#   'retirement plan',
#   'ridiculous mention',
#   'rupee understand',
#   'second understand',
#   'soon possible',
#   'supervisor touch',
#   'think happen',
#   'think help',
#   'today retirement',
#   'touch soon',
#   'understand mean',
#   'understand supervisor',
#   'want invest',
#   'website kindly',
#   'withdraw corpus',
#   'year miss',
#   'year plan'],
#  ['address portal',
#   'address send',
#   'agent come',
#   'agent contact',
#   'agent want',
#   'buying information',
#   'come home',
#   'come send',
#   'contact agent',
#   'contact medication',
#   'early medical',
#   'email query',
#   'hdfcla help',
#   'hello hdfcla',
#   'help want',
#   'home early',
#   'home procedure',
#   'home right',
#   'information know',
#   'internet online',
#   'kevin mobile_number',
#   'know mobile_number',
#   'know option',
#   'link send',
#   'live online',
#   'medical come',
#   'medication home',
#   'mobile_number kevin',
#   'mobile_number want',
#   'number email',
#   'offline agent',
#   'offline online',
#   'online internet',
#   'online link',
#   'online offline',
#   'online send',
#   'online thing',
#   'online want',
#   'option buying',
#   'option offline',
#   'plan want',
#   'plus plan',
#   'portal agent',
#   'procedure right',
#   'query live',
#   'right come',
#   'right signature',
#   'send address',
#   'send message',
#   'send number',
#   'signature online',
#   'thing option',
#   'want contact',
#   'want know',
#   'want offline',
#   'want online',
#   'want plus'],
#  ['account sorry',
#   'actually toll_free',
#   'afternoon welcome',
#   'agent brochure',
#   'apologize inconvenience',
#   'apply agent',
#   'aware usually',
#   'brochure usually',
#   'claim actually',
#   'claim claim',
#   'claim insurance',
#   'claim process',
#   'claim request',
#   'claim response',
#   'claim send',
#   'craig policy_number',
#   'game hour',
#   'good afternoon',
#   'happen apologize',
#   'hell happen',
#   'help young',
#   'hour process',
#   'inconvenience verification',
#   'information long',
#   'information mention',
#   'information option',
#   'insurance policy',
#   'insurance read',
#   'insurance reflect',
#   'know claim',
#   'know hell',
#   'know policy_number',
#   'life help',
#   'long information',
#   'mention information',
#   'mention thing',
#   'mention visit',
#   'number insurance',
#   'number request',
#   'option claim',
#   'payment know',
#   'payment term',
#   'policy payment',
#   'policy_number craig',
#   'policy_number payment',
#   'process claim',
#   'process mention',
#   'purpose know',
#   'read claim',
#   'record game',
#   'reflect account',
#   'request claim',
#   'request record',
#   'response know',
#   'right claim',
#   'send toll_free',
#   'sorry right',
#   'star insurance',
#   'term claim',
#   'thing aware',
#   'toll_free number',
#   'usually apply',
#   'usually mention',
#   'verification purpose',
#   'visit website',
#   'website information',
#   'welcome life',
#   'young star'],
#  ['able figure',
#   'account number',
#   'address right_away',
#   'address thing',
#   'afternoon help',
#   'authentication brother',
#   'away claim',
#   'away type',
#   'behavior expect',
#   'brother claim',
#   'brother ford',
#   'brother phone',
#   'check_right away',
#   'claim correct',
#   'claim process',
#   'claim term',
#   'correct account',
#   'correct address',
#   'correct correct',
#   'correctly able',
#   'expect behavior',
#   'expect switch',
#   'figure poly',
#   'ford policy_number',
#   'good afternoon',
#   'good claim',
#   'happen good',
#   'help claim',
#   'holder address',
#   'inconvenience brother',
#   'insurance soul',
#   'know thing',
#   'maybe check_right',
#   'number authentication',
#   'number policy',
#   'phone number',
#   'policy holder',
#   'policy_number sorry',
#   'policy_number want',
#   'poly policy_number',
#   'process receive',
#   'receive inconvenience',
#   'right thing',
#   'right_away right',
#   'sorry happen',
#   'soul brother',
#   'switch check_right',
#   'term insurance',
#   'thing correct',
#   'thing correctly',
#   'thing maybe',
#   'type expect',
#   'want know'],
#  ['benefit quote',
#   'certainly registration',
#   'claim benefit',
#   'claim plan',
#   'claim policy',
#   'claim ridiculous',
#   'escalate legal_action',
#   'escalate supervisor',
#   'file claim',
#   'hello life',
#   'hello protect',
#   'help escalate',
#   'help hello',
#   'know escalate',
#   'know policy_number',
#   'legal_action understand',
#   'life help',
#   'manager want',
#   'message somebody',
#   'mobile_number certainly',
#   'mobile_number claim',
#   'mobile_number policy_number',
#   'plan somebody',
#   'plan verification',
#   'plus plan',
#   'policy claim',
#   'policy_number mobile_number',
#   'problem truth',
#   'protect plus',
#   'purpose know',
#   'quote legal_action',
#   'registration policy_number',
#   'ridiculous file',
#   'somebody claim',
#   'somebody message',
#   'supervisor manager',
#   'truth help',
#   'understand problem',
#   'verification purpose',
#   'want know'],
#  ['account hour',
#   'afternoon life',
#   'beat policy_number',
#   'benefit think',
#   'care help',
#   'claim pension',
#   'claim process',
#   'claim toll',
#   'complain previously',
#   'customer care',
#   'easy normal',
#   'escalate supervisor',
#   'file plane',
#   'free number',
#   'good afternoon',
#   'happen need',
#   'help today',
#   'hour know',
#   'inconvenience beat',
#   'know claim',
#   'know happen',
#   'know thing',
#   'life customer',
#   'money account',
#   'month term',
#   'need escalate',
#   'need sorry',
#   'normal people',
#   'number money',
#   'pension plus',
#   'people file',
#   'plan complain',
#   'plane process',
#   'plus plan',
#   'policy_number policy_number',
#   'policy_number second',
#   'previously know',
#   'process fast',
#   'process vietnam',
#   'season easy',
#   'second month',
#   'sorry inconvenience',
#   'supervisor claim',
#   'term know',
#   'thing benefit',
#   'think season',
#   'today claim',
#   'toll free',
#   'vietnam need'],
#  ['afternoon help',
#   'agent mobile',
#   'agent online',
#   'agent want',
#   'card card',
#   'card ready',
#   'card think',
#   'check come',
#   'click link',
#   'come check',
#   'come home',
#   'come office',
#   'come problem',
#   'come want',
#   'confirmation mail',
#   'customer click',
#   'doctor come',
#   'document need',
#   'dude service',
#   'easy procedure',
#   'examiner come',
#   'follow document',
#   'garden pond',
#   'good afternoon',
#   'help easy',
#   'help today',
#   'home come',
#   'home dude',
#   'lake pension',
#   'link need',
#   'link register',
#   'mail regard',
#   'mean come',
#   'medical examiner',
#   'medical plan',
#   'medical thing',
#   'mind anytime',
#   'mobile number',
#   'need card',
#   'need separately',
#   'need upload',
#   'number phone',
#   'number pokémon',
#   'office mean',
#   'office week',
#   'ohio lake',
#   'online agent',
#   'online online',
#   'online procedure',
#   'online send',
#   'pension plus',
#   'phone number',
#   'plan medical',
#   'plan processor',
#   'plan website',
#   'plus plan',
#   'pokémon send',
#   'policy step',
#   'pond card',
#   'possible online',
#   'problem question',
#   'procedure help',
#   'procedure website',
#   'processor want',
#   'prompt regard',
#   'question mind',
#   'ready need',
#   'regard medical',
#   'regard policy',
#   'register customer',
#   'register plan',
#   'send agent',
#   'send prompt',
#   'separately doctor',
#   'service register',
#   'step follow',
#   'thing need',
#   'think need',
#   'today ohio',
#   'upload confirmation',
#   'upload garden',
#   'upload medical',
#   'upload send',
#   'want come',
#   'want online',
#   'want possible',
#   'website link',
#   'website upload',
#   'week office'],
#  ['absolute_assignment conditional_assignment',
#   'absolute_assignment policy',
#   'alright attach',
#   'angel phone_number',
#   'angel policy_number',
#   'anymore benefit',
#   'assign policy',
#   'assignee circumstance',
#   'assigner different',
#   'assigning offend',
#   'assignment assign',
#   'assignment process',
#   'assignment valuable',
#   'attach policy',
#   'benefit condition',
#   'benefit policy',
#   'child insurance',
#   'circumstance conditional_assignment',
#   'collateral loan',
#   'condition thing',
#   'conditional_assignment absolute_assignment',
#   'conditional_assignment policy',
#   'conditional_assignment typically',
#   'different anymore',
#   'help high',
#   'high angel',
#   'insurance plan',
#   'insurance policy',
#   'know assignment',
#   'know phone_number',
#   'life help',
#   'loan assignment',
#   'offend policy',
#   'offer verification',
#   'payment benefit',
#   'phone_number angel',
#   'phone_number sorry',
#   'plan offer',
#   'policy absolute_assignment',
#   'policy assignee',
#   'policy assigner',
#   'policy assigning',
#   'policy assignment',
#   'policy collateral',
#   'policy payment',
#   'policy_number policy_number',
#   'policy_number query',
#   'policy_number want',
#   'policyholder transfer',
#   'process policyholder',
#   'purpose know',
#   'query respect',
#   'repeat policy_number',
#   'respect child',
#   'sorry repeat',
#   'thing conditional_assignment',
#   'transfer alright',
#   'typically insurance',
#   'valuable consideration',
#   'verification purpose',
#   'want know',
#   'welcome life']]

# %%
preprocessed_data['Bigram_Transcript']=bigrams

# %%
dictionary = gensim.corpora.Dictionary(preprocessed_data['Bigram_Transcript'])

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_data['Bigram_Transcript']]

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dictionary,                                    
                                   passes =5,
                                   workers = 1)

# %%
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.004*"want know" + 0.004*"premium month" + 0.003*"payment update" + 0.003*"month january" + 0.003*"hour payment" + 0.003*"ignore message" + 0.003*"time payment" + 0.003*"premium time" + 0.003*"good morning" + 0.003*"life help"
#
#
# Topic: 1
# Words: 0.005*"insurance help" + 0.005*"good afternoon" + 0.004*"welcome life" + 0.004*"afternoon welcome" + 0.003*"life insurance" + 0.003*"want know" + 0.003*"help today" + 0.002*"policy number" + 0.002*"welcome insurance" + 0.002*"help want"
#
#
# Topic: 2
# Words: 0.005*"help today" + 0.005*"want know" + 0.004*"customer care" + 0.004*"good afternoon" + 0.004*"care help" + 0.003*"verification purpose" + 0.003*"know policy_number" + 0.003*"life help" + 0.003*"purpose know" + 0.003*"life customer"
#
#
# Topic: 3
# Words: 0.006*"want know" + 0.005*"help today" + 0.004*"good afternoon" + 0.003*"know premium" + 0.003*"know policy_number" + 0.003*"customer care" + 0.003*"care help" + 0.002*"purpose know" + 0.002*"verification purpose" + 0.002*"service type"

# %%
doc_lda = lda_model[bow_corpus]
for topic in doc_lda:
     print("Document Topics      : ", topic)
# Out:
# Document Topics      :  [(2, 0.99509585)]
# Document Topics      :  [(4, 0.99589247)]
# Document Topics      :  [(4, 0.9951832)]
# Document Topics      :  [(0, 0.99512386)]
# Document Topics      :  [(2, 0.995408)]
# Document Topics      :  [(4, 0.9956479)]
# Document Topics      :  [(0, 0.995904)]
# Document Topics      :  [(1, 0.99553454)]
# Document Topics      :  [(0, 0.9968036)]
# Document Topics      :  [(2, 0.9937906)]
# Document Topics      :  [(1, 0.9956531)]
# Document Topics      :  [(0, 0.9958856)]
# Document Topics      :  [(4, 0.99279404)]
# Document Topics      :  [(0, 0.9949151)]
# Document Topics      :  [(1, 0.99478734)]
# Document Topics      :  [(2, 0.99443704)]
# Document Topics      :  [(1, 0.99509674)]
# Document Topics      :  [(1, 0.99600756)]
# Document Topics      :  [(1, 0.9935153)]
# Document Topics      :  [(0, 0.9964994)]
# Document Topics      :  [(4, 0.99481297)]
# Document Topics      :  [(3, 0.99546486)]
# Document Topics      :  [(3, 0.9949249)]
# Document Topics      :  [(1, 0.99523324)]
# Document Topics      :  [(2, 0.99602103)]
# Document Topics      :  [(0, 0.995638)]
# Document Topics      :  [(2, 0.9945369)]
# Document Topics      :  [(2, 0.99444914)]
# Document Topics      :  [(1, 0.99322087)]
# Document Topics      :  [(3, 0.9965435)]
# Document Topics      :  [(2, 0.9953259)]
# Document Topics      :  [(2, 0.9937512)]
# Document Topics      :  [(2, 0.9946297)]
# Document Topics      :  [(1, 0.9938283)]
# Document Topics      :  [(0, 0.99599004)]
# Document Topics      :  [(2, 0.99496263)]
# Document Topics      :  [(3, 0.9948291)]
# Document Topics      :  [(1, 0.9944518)]
# Document Topics      :  [(0, 0.9959755)]
# Document Topics      :  [(2, 0.9933936)]
# Document Topics      :  [(2, 0.9946221)]
# Document Topics      :  [(2, 0.9935115)]
# Document Topics      :  [(4, 0.99389523)]
# Document Topics      :  [(2, 0.994065)]
# Document Topics      :  [(1, 0.99516946)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(2, 0.99498045)]
# Document Topics      :  [(1, 0.99624985)]
# Document Topics      :  [(1, 0.99224037)]
# Document Topics      :  [(2, 0.9939844)]
# Document Topics      :  [(0, 0.9949156)]
# Document Topics      :  [(4, 0.9955263)]
# Document Topics      :  [(2, 0.9946191)]
# Document Topics      :  [(4, 0.99395585)]
# Document Topics      :  [(0, 0.99497235)]
# Document Topics      :  [(1, 0.99343747)]
# Document Topics      :  [(0, 0.9953062)]
# Document Topics      :  [(1, 0.99530244)]
# Document Topics      :  [(3, 0.9954181)]
# Document Topics      :  [(1, 0.9948826)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(1, 0.9958289)]
# Document Topics      :  [(1, 0.9944158)]
# Document Topics      :  [(0, 0.99581116)]
# Document Topics      :  [(2, 0.9952316)]
# Document Topics      :  [(0, 0.99573886)]
# Document Topics      :  [(2, 0.9943342)]
# Document Topics      :  [(2, 0.9945316)]
# Document Topics      :  [(4, 0.99600756)]
# Document Topics      :  [(0, 0.992148)]
# Document Topics      :  [(2, 0.9929921)]
# Document Topics      :  [(2, 0.99423933)]
# Document Topics      :  [(3, 0.99596477)]
# Document Topics      :  [(0, 0.36781716), (2, 0.6285878)]
# Document Topics      :  [(2, 0.995408)]
# Document Topics      :  [(0, 0.9958082)]
# Document Topics      :  [(4, 0.994327)]
# Document Topics      :  [(4, 0.9945495)]
# Document Topics      :  [(3, 0.9948964)]
# Document Topics      :  [(2, 0.99529076)]
# Document Topics      :  [(2, 0.99451053)]
# Document Topics      :  [(0, 0.99527717)]
# Document Topics      :  [(3, 0.9945224)]
# Document Topics      :  [(2, 0.9957208)]
# Document Topics      :  [(2, 0.9947016)]
# Document Topics      :  [(1, 0.9956533)]
# Document Topics      :  [(2, 0.9944803)]
# Document Topics      :  [(4, 0.9927143)]
# Document Topics      :  [(1, 0.9942902)]
# Document Topics      :  [(2, 0.99664366)]
# Document Topics      :  [(4, 0.9952324)]

# %% [markdown]
# ### LDA with trigrams

# %%
# Getting trigram  
vectorizer = CountVectorizer(ngram_range = (3,3)) 
X1=vectorizer.fit_transform(preprocessed_data['Preprocessed Transcripts'])
trigrams=[]
for text in preprocessed_data['Preprocessed Transcripts']:
    text=[text,]
    X1=(vectorizer.fit_transform(text))
    trigrams.append(vectorizer.get_feature_names()) 

preprocessed_data['trigram_Transcript']=trigrams
dictionary = gensim.corpora.Dictionary(preprocessed_data['trigram_Transcript'])
bow_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_data['trigram_Transcript']]
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dictionary,                                    
                                   passes =5,
                                   workers = 1)
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.003*"customer care help" + 0.003*"care help today" + 0.002*"good afternoon life" + 0.002*"life customer care" + 0.002*"afternoon life customer" + 0.001*"help today want" + 0.001*"insurance help want" + 0.001*"want know premium" + 0.001*"number phone number" + 0.001*"welcome insurance help"
#
#
# Topic: 1
# Words: 0.003*"verification purpose know" + 0.003*"purpose know policy_number" + 0.003*"hour payment update" + 0.003*"premium month january" + 0.002*"month january possible" + 0.002*"ignore message receive" + 0.002*"message receive today" + 0.002*"kindly ignore message" + 0.002*"confirmation message regard" + 0.002*"help premium time"
#
#
# Topic: 2
# Words: 0.003*"verification purpose know" + 0.002*"good afternoon welcome" + 0.002*"purpose know policy_number" + 0.002*"life insurance help" + 0.002*"welcome life insurance" + 0.002*"toll_free number insurance" + 0.002*"inconvenience verification purpose" + 0.002*"number request claim" + 0.002*"toll_free number request" + 0.002*"apologize inconvenience verification"
#
#
# Topic: 3
# Words: 0.003*"customer care help" + 0.003*"care help today" + 0.003*"life customer care" + 0.002*"want know premium" + 0.002*"unit link plan" + 0.002*"life insurance help" + 0.002*"welcome life insurance" + 0.001*"good afternoon life" + 0.001*"afternoon life customer" + 0.001*"good morning life"

# %%
doc_lda = lda_model[bow_corpus]
for topic in doc_lda:
     print("Document Topics      : ", topic)
# Out:
# Document Topics      :  [(2, 0.99509585)]
# Document Topics      :  [(4, 0.99589247)]
# Document Topics      :  [(4, 0.9951832)]
# Document Topics      :  [(0, 0.99512404)]
# Document Topics      :  [(2, 0.995408)]
# Document Topics      :  [(4, 0.99564785)]
# Document Topics      :  [(0, 0.9959039)]
# Document Topics      :  [(1, 0.99553454)]
# Document Topics      :  [(0, 0.9968036)]
# Document Topics      :  [(2, 0.99379224)]
# Document Topics      :  [(1, 0.9956531)]
# Document Topics      :  [(0, 0.99588567)]
# Document Topics      :  [(4, 0.99279404)]
# Document Topics      :  [(0, 0.99491525)]
# Document Topics      :  [(1, 0.99478745)]
# Document Topics      :  [(2, 0.994437)]
# Document Topics      :  [(1, 0.99509674)]
# Document Topics      :  [(1, 0.9960069)]
# Document Topics      :  [(1, 0.9935154)]
# Document Topics      :  [(0, 0.9964994)]
# Document Topics      :  [(4, 0.9948125)]
# Document Topics      :  [(3, 0.99546486)]
# Document Topics      :  [(3, 0.9949249)]
# Document Topics      :  [(1, 0.99523324)]
# Document Topics      :  [(2, 0.9960206)]
# Document Topics      :  [(0, 0.995638)]
# Document Topics      :  [(2, 0.994537)]
# Document Topics      :  [(2, 0.99444944)]
# Document Topics      :  [(1, 0.993221)]
# Document Topics      :  [(3, 0.9965436)]
# Document Topics      :  [(2, 0.9953258)]
# Document Topics      :  [(2, 0.99375135)]
# Document Topics      :  [(2, 0.9946297)]
# Document Topics      :  [(1, 0.99382806)]
# Document Topics      :  [(0, 0.9959901)]
# Document Topics      :  [(2, 0.99496275)]
# Document Topics      :  [(3, 0.9948291)]
# Document Topics      :  [(1, 0.9944518)]
# Document Topics      :  [(0, 0.9959755)]
# Document Topics      :  [(2, 0.99339366)]
# Document Topics      :  [(2, 0.9946221)]
# Document Topics      :  [(2, 0.9935114)]
# Document Topics      :  [(4, 0.99389523)]
# Document Topics      :  [(2, 0.9940651)]
# Document Topics      :  [(1, 0.99516875)]
# Document Topics      :  [(2, 0.9935214)]
# Document Topics      :  [(2, 0.9949808)]
# Document Topics      :  [(1, 0.9962498)]
# Document Topics      :  [(1, 0.9922401)]
# Document Topics      :  [(2, 0.9939844)]
# Document Topics      :  [(0, 0.9949151)]
# Document Topics      :  [(4, 0.9955263)]
# Document Topics      :  [(2, 0.9946191)]
# Document Topics      :  [(4, 0.99395585)]
# Document Topics      :  [(0, 0.99497235)]
# Document Topics      :  [(1, 0.9934363)]
# Document Topics      :  [(0, 0.995306)]
# Document Topics      :  [(1, 0.99530244)]
# Document Topics      :  [(3, 0.99541813)]
# Document Topics      :  [(1, 0.9948827)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(1, 0.9958289)]
# Document Topics      :  [(1, 0.99441636)]
# Document Topics      :  [(0, 0.99581116)]
# Document Topics      :  [(2, 0.9952315)]
# Document Topics      :  [(0, 0.99573886)]
# Document Topics      :  [(2, 0.9943341)]
# Document Topics      :  [(2, 0.99453115)]
# Document Topics      :  [(4, 0.996008)]
# Document Topics      :  [(0, 0.9921482)]
# Document Topics      :  [(2, 0.9929921)]
# Document Topics      :  [(2, 0.9942391)]
# Document Topics      :  [(3, 0.99596477)]
# Document Topics      :  [(0, 0.3678178), (2, 0.6285871)]
# Document Topics      :  [(2, 0.99540806)]
# Document Topics      :  [(0, 0.9958082)]
# Document Topics      :  [(4, 0.994327)]
# Document Topics      :  [(4, 0.9945495)]
# Document Topics      :  [(3, 0.9948964)]
# Document Topics      :  [(2, 0.99529076)]
# Document Topics      :  [(2, 0.99451053)]
# Document Topics      :  [(0, 0.9952771)]
# Document Topics      :  [(3, 0.9945244)]
# Document Topics      :  [(2, 0.9957208)]
# Document Topics      :  [(2, 0.9947016)]
# Document Topics      :  [(1, 0.995653)]
# Document Topics      :  [(2, 0.9944803)]
# Document Topics      :  [(4, 0.992713)]
# Document Topics      :  [(1, 0.99429005)]
# Document Topics      :  [(2, 0.99664336)]
# Document Topics      :  [(4, 0.9952324)]

# %% [markdown]
# ### LDA with unigram,bigram,trigram

# %%
# Getting unigram,bigram,trigram  
vectorizer = CountVectorizer(ngram_range = (1,3)) 
X1=vectorizer.fit_transform(preprocessed_data['Preprocessed Transcripts'])
trigrams=[]
for text in preprocessed_data['Preprocessed Transcripts']:
    text=[text,]
    X1=(vectorizer.fit_transform(text))
    trigrams.append(vectorizer.get_feature_names()) 

preprocessed_data['trigram_Transcript']=trigrams
dictionary = gensim.corpora.Dictionary(preprocessed_data['trigram_Transcript'])
bow_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_data['trigram_Transcript']]
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 5, 
                                   id2word = dictionary,                                    
                                   passes =5,
                                   workers = 1)
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.004*"help" + 0.003*"policy" + 0.003*"want" + 0.003*"know" + 0.003*"premium" + 0.002*"time" + 0.002*"sorry" + 0.002*"good" + 0.002*"plan" + 0.002*"insurance"
#
#
# Topic: 1
# Words: 0.004*"help" + 0.004*"know" + 0.003*"good" + 0.003*"life" + 0.003*"policy_number" + 0.003*"right" + 0.003*"payment" + 0.002*"today" + 0.002*"afternoon" + 0.002*"thing"
#
#
# Topic: 2
# Words: 0.005*"help" + 0.004*"know" + 0.004*"want" + 0.004*"plan" + 0.003*"life" + 0.003*"today" + 0.003*"policy" + 0.002*"policy_number" + 0.002*"good" + 0.002*"help today"
#
#
# Topic: 3
# Words: 0.003*"want" + 0.003*"help" + 0.002*"know" + 0.002*"plan" + 0.002*"insurance" + 0.002*"premium" + 0.002*"need" + 0.002*"time" + 0.002*"payment" + 0.002*"want know"
#
#
# Topic: 4
# Words: 0.003*"help" + 0.003*"want" + 0.003*"know" + 0.002*"plan" + 0.002*"benefit" + 0.002*"want know" + 0.002*"life" + 0.002*"policy" + 0.002*"insurance" + 0.002*"welcome"

# %%
doc_lda = lda_model[bow_corpus]
for topic in doc_lda:
    print("Document Topics      : ", topic)
# Out:
# Document Topics      :  [(2, 0.99509585)]
# Document Topics      :  [(4, 0.99589247)]
# Document Topics      :  [(4, 0.9951832)]
# Document Topics      :  [(0, 0.9951239)]
# Document Topics      :  [(2, 0.99540806)]
# Document Topics      :  [(4, 0.995648)]
# Document Topics      :  [(0, 0.9959039)]
# Document Topics      :  [(1, 0.99553454)]
# Document Topics      :  [(0, 0.9968035)]
# Document Topics      :  [(2, 0.99379224)]
# Document Topics      :  [(1, 0.99565315)]
# Document Topics      :  [(0, 0.9958857)]
# Document Topics      :  [(4, 0.9927942)]
# Document Topics      :  [(0, 0.9949156)]
# Document Topics      :  [(1, 0.99478734)]
# Document Topics      :  [(2, 0.994437)]
# Document Topics      :  [(1, 0.99509674)]
# Document Topics      :  [(1, 0.99600756)]
# Document Topics      :  [(1, 0.9935154)]
# Document Topics      :  [(0, 0.9964995)]
# Document Topics      :  [(4, 0.99481297)]
# Document Topics      :  [(3, 0.99546427)]
# Document Topics      :  [(3, 0.994925)]
# Document Topics      :  [(1, 0.99523324)]
# Document Topics      :  [(2, 0.9960208)]
# Document Topics      :  [(0, 0.995638)]
# Document Topics      :  [(2, 0.99453646)]
# Document Topics      :  [(2, 0.99444896)]
# Document Topics      :  [(1, 0.993221)]
# Document Topics      :  [(3, 0.9965436)]
# Document Topics      :  [(2, 0.99532574)]
# Document Topics      :  [(2, 0.9937512)]
# Document Topics      :  [(2, 0.9946298)]
# Document Topics      :  [(1, 0.9938284)]
# Document Topics      :  [(0, 0.99599016)]
# Document Topics      :  [(2, 0.99496275)]
# Document Topics      :  [(3, 0.9948292)]
# Document Topics      :  [(1, 0.9944518)]
# Document Topics      :  [(0, 0.9959755)]
# Document Topics      :  [(2, 0.99339366)]
# Document Topics      :  [(2, 0.9946219)]
# Document Topics      :  [(2, 0.9935115)]
# Document Topics      :  [(4, 0.99389523)]
# Document Topics      :  [(2, 0.994065)]
# Document Topics      :  [(1, 0.99516886)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(2, 0.9949806)]
# Document Topics      :  [(1, 0.99624985)]
# Document Topics      :  [(1, 0.99224067)]
# Document Topics      :  [(2, 0.9939844)]
# Document Topics      :  [(0, 0.9949156)]
# Document Topics      :  [(4, 0.99552643)]
# Document Topics      :  [(2, 0.99461895)]
# Document Topics      :  [(4, 0.99395585)]
# Document Topics      :  [(0, 0.99497235)]
# Document Topics      :  [(1, 0.9934374)]
# Document Topics      :  [(0, 0.9953062)]
# Document Topics      :  [(1, 0.99530244)]
# Document Topics      :  [(3, 0.9954181)]
# Document Topics      :  [(1, 0.9948827)]
# Document Topics      :  [(2, 0.99352145)]
# Document Topics      :  [(1, 0.9958289)]
# Document Topics      :  [(1, 0.9944155)]
# Document Topics      :  [(0, 0.99581116)]
# Document Topics      :  [(2, 0.9952317)]
# Document Topics      :  [(0, 0.9957388)]
# Document Topics      :  [(2, 0.9943342)]
# Document Topics      :  [(2, 0.9945317)]
# Document Topics      :  [(4, 0.9960073)]
# Document Topics      :  [(0, 0.9921481)]
# Document Topics      :  [(2, 0.9929921)]
# Document Topics      :  [(2, 0.99423975)]
# Document Topics      :  [(3, 0.9959648)]
# Document Topics      :  [(0, 0.36781594), (2, 0.62858903)]
# Document Topics      :  [(2, 0.99540806)]
# Document Topics      :  [(0, 0.9958082)]
# Document Topics      :  [(4, 0.994327)]
# Document Topics      :  [(4, 0.9945495)]
# Document Topics      :  [(3, 0.99489653)]
# Document Topics      :  [(2, 0.99529076)]
# Document Topics      :  [(2, 0.99451053)]
# Document Topics      :  [(0, 0.9952771)]
# Document Topics      :  [(3, 0.994523)]
# Document Topics      :  [(2, 0.9957208)]
# Document Topics      :  [(2, 0.9947015)]
# Document Topics      :  [(1, 0.9956529)]
# Document Topics      :  [(2, 0.99448043)]
# Document Topics      :  [(4, 0.99271417)]
# Document Topics      :  [(1, 0.99429005)]
# Document Topics      :  [(2, 0.9966435)]
# Document Topics      :  [(4, 0.9952324)]

# %%
doc_lda

# %%
trigrams
# Out:
# [['account',
#   'account register',
#   'account register line',
#   'alright',
#   'alright unit',
#   'alright unit link',
#   'angel',
#   'angel policy_number',
#   'angel policy_number second',
#   'assist',
#   'assist maybe',
#   'assist maybe registration_process',
#   'check',
#   'check phone',
#   'check phone value',
#   'check value',
#   'check value policy',
#   'child',
#   'child policy',
#   'child policy want',
#   'chill',
#   'chill insurance',
#   'chill insurance verification',
#   'continuous',
#   'continuous update',
#   'continuous update fine',
#   'easy',
#   'easy time',
#   'easy time registration',
#   'facility',
#   'facility registration_process',
#   'facility registration_process icsi',
#   'fine',
#   'fine register',
#   'fine register service',
#   'hello',
#   'hello child',
#   'hello child policy',
#   'help',
#   'help hello',
#   'help hello child',
#   'icsi',
#   'icsi insurance',
#   'icsi insurance registering',
#   'inform',
#   'inform assist',
#   'inform assist maybe',
#   'insurance',
#   'insurance registering',
#   'insurance registering procedure',
#   'insurance verification',
#   'insurance verification purpose',
#   'know',
#   'know check',
#   'know check phone',
#   'know policy_number',
#   'know policy_number angel',
#   'life',
#   'life help',
#   'life help hello',
#   'life pleasant',
#   'line',
#   'line register',
#   'line register facility',
#   'link',
#   'link policy',
#   'link policy want',
#   'maybe',
#   'maybe registration_process',
#   'maybe registration_process life',
#   'phone',
#   'phone value',
#   'phone value policy',
#   'pleasant',
#   'policy',
#   'policy chill',
#   'policy chill insurance',
#   'policy policy',
#   'policy policy summary',
#   'policy summary',
#   'policy summary section',
#   'policy want',
#   'policy want inform',
#   'policy want know',
#   'policy_number',
#   'policy_number alright',
#   'policy_number alright unit',
#   'policy_number angel',
#   'policy_number angel policy_number',
#   'policy_number second',
#   'policy_number second check',
#   'post',
#   'post continuous',
#   'post continuous update',
#   'procedure',
#   'procedure easy',
#   'procedure easy time',
#   'process',
#   'process post',
#   'process post continuous',
#   'purpose',
#   'purpose know',
#   'purpose know policy_number',
#   'register',
#   'register facility',
#   'register facility registration_process',
#   'register line',
#   'register line register',
#   'register service',
#   'register service type',
#   'registering',
#   'registering procedure',
#   'registering procedure easy',
#   'registration',
#   'registration process',
#   'registration process post',
#   'registration_process',
#   'registration_process icsi',
#   'registration_process icsi insurance',
#   'registration_process life',
#   'registration_process life pleasant',
#   'second',
#   'second check',
#   'second check value',
#   'section',
#   'section account',
#   'section account register',
#   'service',
#   'service type',
#   'service type space',
#   'space',
#   'space policy_number',
#   'space policy_number alright',
#   'summary',
#   'summary section',
#   'summary section account',
#   'time',
#   'time registration',
#   'time registration process',
#   'type',
#   'type space',
#   'type space policy_number',
#   'unit',
#   'unit link',
#   'unit link policy',
#   'update',
#   'update fine',
#   'update fine register',
#   'value',
#   'value policy',
#   'value policy chill',
#   'value policy policy',
#   'verification',
#   'verification purpose',
#   'verification purpose know',
#   'want',
#   'want inform',
#   'want inform assist',
#   'want know',
#   'want know check',
#   'welcome',
#   'welcome life',
#   'welcome life help'],
#  ['afternoon',
#   'afternoon customer',
#   'afternoon customer care',
#   'agent',
#   'agent touch',
#   'agent touch come',
#   'agree',
#   'agree confirmation',
#   'agree confirmation minimum',
#   'angel',
#   'angel mobile_number',
#   'angel mobile_number want',
#   'benefit',
#   'benefit agree',
#   'benefit agree confirmation',
#   'card',
#   'card card',
#   'card card photo',
#   'card photo',
#   'card photo graph',
#   'care',
#   'care help',
#   'care help today',
#   'collect',
#   'collect document',
#   'collect document online',
#   'come',
#   'come collect',
#   'come collect document',
#   'confirmation',
#   'confirmation minimum',
#   'confirmation minimum premium',
#   'contact',
#   'contact write',
#   'contact write mail',
#   'contact yeah_sure',
#   'contact yeah_sure contact',
#   'customer',
#   'customer care',
#   'customer care help',
#   'document',
#   'document need',
#   'document need upload',
#   'document online',
#   'document online easy',
#   'easily',
#   'easily agent',
#   'easily agent touch',
#   'easy',
#   'easy online',
#   'easy online processor',
#   'enroll',
#   'enroll easily',
#   'enroll easily agent',
#   'enroll immediately',
#   'enroll immediately enroll',
#   'everybody',
#   'everybody understand',
#   'everybody understand website',
#   'good',
#   'good afternoon',
#   'good afternoon customer',
#   'graph',
#   'graph passport',
#   'graph passport size',
#   'great',
#   'help',
#   'help know',
#   'help know problem',
#   'help today',
#   'help today want',
#   'help yeah_sure',
#   'help yeah_sure mobile_number',
#   'immediately',
#   'immediately enroll',
#   'immediately enroll easily',
#   'information',
#   'information help',
#   'information help know',
#   'information unit_link',
#   'information unit_link plan',
#   'know',
#   'know premium',
#   'know premium benefit',
#   'know problem',
#   'know problem contact',
#   'know procedure',
#   'know procedure enroll',
#   'know want',
#   'know want information',
#   'mail',
#   'mail query',
#   'mail query ratehdfclife',
#   'mention',
#   'mention document',
#   'mention document need',
#   'minimum',
#   'minimum premium',
#   'minimum premium yearly',
#   'mobile_number',
#   'mobile_number angel',
#   'mobile_number angel mobile_number',
#   'mobile_number want',
#   'mobile_number want know',
#   'need',
#   'need card',
#   'need card card',
#   'need upload',
#   'need upload everybody',
#   'need upload website',
#   'online',
#   'online easy',
#   'online easy online',
#   'online processor',
#   'online processor mention',
#   'option',
#   'option register',
#   'option register need',
#   'passport',
#   'passport size',
#   'passport size need',
#   'photo',
#   'photo graph',
#   'photo graph passport',
#   'plan',
#   'plan help',
#   'plan help yeah_sure',
#   'plan know',
#   'plan know premium',
#   'premium',
#   'premium benefit',
#   'premium benefit agree',
#   'premium yearly',
#   'premium yearly want',
#   'problem',
#   'problem contact',
#   'problem contact yeah_sure',
#   'procedure',
#   'procedure enroll',
#   'procedure enroll immediately',
#   'processor',
#   'processor mention',
#   'processor mention document',
#   'query',
#   'query ratehdfclife',
#   'query ratehdfclife great',
#   'ratehdfclife',
#   'ratehdfclife great',
#   'register',
#   'register need',
#   'register need card',
#   'size',
#   'size need',
#   'size need upload',
#   'today',
#   'today want',
#   'today want unit_link',
#   'touch',
#   'touch come',
#   'touch come collect',
#   'understand',
#   'understand website',
#   'understand website option',
#   'unit_link',
#   'unit_link plan',
#   'unit_link plan help',
#   'unit_link plan know',
#   'upload',
#   'upload everybody',
#   'upload everybody understand',
#   'upload website',
#   'upload website information',
#   'want',
#   'want information',
#   'want information unit_link',
#   'want know',
#   'want know procedure',
#   'want know want',
#   'want unit_link',
#   'want unit_link plan',
#   'website',
#   'website information',
#   'website information help',
#   'website option',
#   'website option register',
#   'write',
#   'write mail',
#   'write mail query',
#   'yeah_sure',
#   'yeah_sure contact',
#   'yeah_sure contact write',
#   'yeah_sure mobile_number',
#   'yeah_sure mobile_number angel',
#   'yearly',
#   'yearly want',
#   'yearly want know'],
#  ['accord',
#   'accord madam_uh',
#   'accord madam_uh accord',
#   'accord plan',
#   'accord plan plan',
#   'assume',
#   'assume inquire',
#   'assume inquire surgical',
#   'band',
#   'band plan',
#   'band plan good',
#   'benefit',
#   'benefit cover',
#   'benefit cover plan',
#   'benefit plan',
#   'benefit plan daily',
#   'benefit plan true',
#   'benefit plus',
#   'benefit plus critical',
#   'benefit work',
#   'benefit work maybe',
#   'cash',
#   'cash benefit',
#   'cash benefit plan',
#   'ciara',
#   'ciara phone',
#   'ciara phone number',
#   'cover',
#   'cover plan',
#   'cover plan band',
#   'critical',
#   'critical illness',
#   'critical illness benefit',
#   'daily',
#   'daily hospital',
#   'daily hospital cash',
#   'explain',
#   'explain benefit',
#   'explain benefit cover',
#   'good',
#   'good accord',
#   'good accord madam_uh',
#   'good morning',
#   'good morning welcome',
#   'health_plan',
#   'health_plan know',
#   'health_plan know know',
#   'health_plan want',
#   'health_plan want know',
#   'help',
#   'help want',
#   'help want read',
#   'hospital',
#   'hospital cash',
#   'hospital cash benefit',
#   'illness',
#   'illness benefit',
#   'illness benefit plan',
#   'information',
#   'information protected_health',
#   'information protected_health plan',
#   'inquire',
#   'inquire surgical',
#   'inquire surgical benefit',
#   'insurance',
#   'insurance help',
#   'insurance help want',
#   'know',
#   'know benefit',
#   'know benefit work',
#   'know know',
#   'know know number',
#   'know know option',
#   'know number',
#   'know number ciara',
#   'know option',
#   'know option want',
#   'know requirement',
#   'know requirement madam_uh',
#   'madam_uh',
#   'madam_uh accord',
#   'madam_uh accord plan',
#   'madam_uh assume',
#   'madam_uh assume inquire',
#   'maybe',
#   'maybe refer',
#   'maybe refer protected_health',
#   'minute',
#   'minute explain',
#   'minute explain benefit',
#   'morning',
#   'morning welcome',
#   'morning welcome insurance',
#   'number',
#   'number ciara',
#   'number ciara phone',
#   'number information',
#   'number information protected_health',
#   'option',
#   'option minute',
#   'option minute explain',
#   'option want',
#   'option want know',
#   'personal',
#   'personal health_plan',
#   'personal health_plan want',
#   'phone',
#   'phone number',
#   'phone number information',
#   'plan',
#   'plan band',
#   'plan band plan',
#   'plan daily',
#   'plan daily hospital',
#   'plan good',
#   'plan good accord',
#   'plan know',
#   'plan know requirement',
#   'plan option',
#   'plan option minute',
#   'plan plan',
#   'plan plan know',
#   'plan plan option',
#   'plan sorry',
#   'plan sorry protect',
#   'plan true',
#   'plan true plan',
#   'plus',
#   'plus critical',
#   'plus critical illness',
#   'protect',
#   'protect health_plan',
#   'protect health_plan know',
#   'protected_health',
#   'protected_health plan',
#   'protected_health plan plan',
#   'protected_health plan sorry',
#   'read',
#   'read personal',
#   'read personal health_plan',
#   'refer',
#   'refer protected_health',
#   'refer protected_health plan',
#   'requirement',
#   'requirement madam_uh',
#   'requirement madam_uh assume',
#   'sorry',
#   'sorry protect',
#   'sorry protect health_plan',
#   'surgical',
#   'surgical benefit',
#   'surgical benefit plus',
#   'true',
#   'true plan',
#   'want',
#   'want know',
#   'want know benefit',
#   'want know know',
#   'want read',
#   'want read personal',
#   'welcome',
#   'welcome insurance',
#   'welcome insurance help',
#   'work',
#   'work maybe',
#   'work maybe refer'],
#  ['afternoon',
#   'afternoon customer',
#   'afternoon customer care',
#   'assure',
#   'assure pension_plan',
#   'assure pension_plan unit_link',
#   'assure unit_link',
#   'assure unit_link plan',
#   'care',
#   'care help',
#   'care help today',
#   'charge',
#   'charge pension',
#   'charge pension super',
#   'charge tax_benefit',
#   'charge tax_benefit flexible',
#   'currently',
#   'currently offer',
#   'currently offer pension_plan',
#   'customer',
#   'customer care',
#   'customer care help',
#   'earlier',
#   'earlier popular',
#   'earlier popular return',
#   'flexible',
#   'flexible maturity',
#   'flexible maturity work',
#   'flexible_premium',
#   'flexible_premium payment',
#   'flexible_premium payment frequency',
#   'flexible_premium payment multiple',
#   'frequency',
#   'frequency tax_benefit',
#   'frequency tax_benefit zero_allocation',
#   'fund',
#   'fund zero_allocation',
#   'fund zero_allocation charge',
#   'good',
#   'good afternoon',
#   'good afternoon customer',
#   'help',
#   'help today',
#   'help today type',
#   'high',
#   'high return',
#   'high return link',
#   'information',
#   'information want',
#   'information want thing',
#   'link',
#   'link market',
#   'link market want',
#   'market',
#   'market want',
#   'market want think',
#   'maturity',
#   'maturity work',
#   'maturity work plan',
#   'multiple',
#   'multiple fund',
#   'multiple fund zero_allocation',
#   'offer',
#   'offer flexible_premium',
#   'offer flexible_premium payment',
#   'offer pension_plan',
#   'offer pension_plan assure',
#   'online',
#   'online want',
#   'payment',
#   'payment frequency',
#   'payment frequency tax_benefit',
#   'payment multiple',
#   'payment multiple fund',
#   'pension',
#   'pension phone_number',
#   'pension phone_number phone_number',
#   'pension super',
#   'pension super plus',
#   'pension_plan',
#   'pension_plan assure',
#   'pension_plan assure pension_plan',
#   'pension_plan offer',
#   'pension_plan offer flexible_premium',
#   'pension_plan unit_link',
#   'pension_plan unit_link pension_plan',
#   'people',
#   'people popular',
#   'people popular plan',
#   'phone_number',
#   'phone_number currently',
#   'phone_number currently offer',
#   'phone_number phone_number',
#   'phone_number phone_number currently',
#   'plan',
#   'plan assure',
#   'plan assure unit_link',
#   'plan earlier',
#   'plan earlier popular',
#   'plan flexible_premium',
#   'plan flexible_premium payment',
#   'plan suggest',
#   'plan suggest people',
#   'plan unit_link',
#   'plan unit_link plan',
#   'planet',
#   'planet high',
#   'planet high return',
#   'plus',
#   'plus plan',
#   'plus plan unit_link',
#   'popular',
#   'popular plan',
#   'popular plan assure',
#   'popular return',
#   'popular return planet',
#   'return',
#   'return link',
#   'return link market',
#   'return planet',
#   'return planet high',
#   'suggest',
#   'suggest people',
#   'suggest people popular',
#   'super',
#   'super plus',
#   'super plus plan',
#   'tax_benefit',
#   'tax_benefit flexible',
#   'tax_benefit flexible maturity',
#   'tax_benefit zero_allocation',
#   'tax_benefit zero_allocation charge',
#   'thing',
#   'thing online',
#   'thing online want',
#   'think',
#   'think time',
#   'think time information',
#   'time',
#   'time information',
#   'time information want',
#   'today',
#   'today type',
#   'today type pension',
#   'type',
#   'type pension',
#   'type pension phone_number',
#   'unit_link',
#   'unit_link pension_plan',
#   'unit_link pension_plan offer',
#   'unit_link plan',
#   'unit_link plan earlier',
#   'unit_link plan flexible_premium',
#   'want',
#   'want thing',
#   'want thing online',
#   'want think',
#   'want think time',
#   'work',
#   'work plan',
#   'work plan suggest',
#   'zero_allocation',
#   'zero_allocation charge',
#   'zero_allocation charge pension',
#   'zero_allocation charge tax_benefit'],
#  ['activate',
#   'activate online_portal',
#   'activate online_portal know',
#   'agent',
#   'agent know',
#   'agent know premium',
#   'agent solve',
#   'agent solve problem',
#   'agent talk',
#   'agent talk right',
#   'agent thing',
#   'agent thing pension_plan',
#   'azure',
#   'azure pension_plan',
#   'azure pension_plan come',
#   'benefit',
#   'benefit agent',
#   'benefit agent thing',
#   'benefit policy',
#   'benefit policy number',
#   'care',
#   'care help',
#   'care help today',
#   'change',
#   'change agent',
#   'change agent talk',
#   'come',
#   'come unit',
#   'come unit link',
#   'contact',
#   'contact agent',
#   'contact agent know',
#   'currently',
#   'currently enable',
#   'currently enable online',
#   'customer',
#   'customer care',
#   'customer care help',
#   'deal',
#   'deal people_uh',
#   'deal people_uh premium',
#   'enable',
#   'enable minute',
#   'enable online',
#   'enable online thing',
#   'enable thing',
#   'enable thing help',
#   'enable want',
#   'enable want enable',
#   'graph',
#   'graph noon',
#   'graph noon life',
#   'handle',
#   'handle agent',
#   'handle agent solve',
#   'hello',
#   'hello history',
#   'hello history life',
#   'help',
#   'help contact',
#   'help contact agent',
#   'help enable',
#   'help enable minute',
#   'help today',
#   'help today hello',
#   'history',
#   'history life',
#   'history life azure',
#   'know',
#   'know premium',
#   'know premium benefit',
#   'know premium yard',
#   'know usually',
#   'know usually people_uh',
#   'life',
#   'life azure',
#   'life azure pension_plan',
#   'life customer',
#   'life customer care',
#   'link',
#   'link plan',
#   'link plan currently',
#   'minute',
#   'minute premium',
#   'minute premium help',
#   'mommy',
#   'mommy want',
#   'mommy want online',
#   'need',
#   'need change',
#   'need change agent',
#   'need enable',
#   'need enable want',
#   'noon',
#   'noon life',
#   'noon life customer',
#   'number',
#   'number minute',
#   'number minute premium',
#   'online',
#   'online need',
#   'online need enable',
#   'online thing',
#   'online thing thing',
#   'online_portal',
#   'online_portal activate',
#   'online_portal activate online_portal',
#   'online_portal know',
#   'online_portal know usually',
#   'pension_plan',
#   'pension_plan come',
#   'pension_plan come unit',
#   'pension_plan online_portal',
#   'pension_plan online_portal activate',
#   'people_uh',
#   'people_uh deal',
#   'people_uh deal people_uh',
#   'people_uh premium',
#   'people_uh premium handle',
#   'plan',
#   'plan currently',
#   'plan currently enable',
#   'policy',
#   'policy number',
#   'policy number minute',
#   'premium',
#   'premium benefit',
#   'premium benefit policy',
#   'premium handle',
#   'premium handle agent',
#   'premium help',
#   'premium help contact',
#   'premium yard',
#   'premium yard benefit',
#   'problem',
#   'problem need',
#   'problem need change',
#   'right',
#   'right mommy',
#   'right mommy want',
#   'solve',
#   'solve problem',
#   'solve problem need',
#   'talk',
#   'talk right',
#   'talk right mommy',
#   'thing',
#   'thing help',
#   'thing help enable',
#   'thing pension_plan',
#   'thing pension_plan online_portal',
#   'thing thing',
#   'thing thing want',
#   'thing want',
#   'thing want know',
#   'today',
#   'today hello',
#   'today hello history',
#   'unit',
#   'unit link',
#   'unit link plan',
#   'usually',
#   'usually people_uh',
#   'usually people_uh deal',
#   'want',
#   'want enable',
#   'want enable thing',
#   'want know',
#   'want know premium',
#   'want online',
#   'want online need',
#   'yard',
#   'yard benefit',
#   'yard benefit agent'],
#  ['actually',
#   'actually benefit',
#   'actually benefit depend',
#   'alright',
#   'alright alright',
#   'alright alright history',
#   'alright history',
#   'alright history nice',
#   'apply',
#   'apply online',
#   'apply online apply',
#   'apply online possible',
#   'bank',
#   'bank share',
#   'bank share right',
#   'benefit',
#   'benefit actually',
#   'benefit actually benefit',
#   'benefit cross',
#   'benefit cross thing',
#   'benefit depend',
#   'benefit depend type',
#   'benefit term_insurance',
#   'benefit term_insurance life',
#   'case',
#   'case death',
#   'case death insure',
#   'company',
#   'company bank',
#   'company bank share',
#   'company insurance_company',
#   'company insurance_company apply',
#   'coverage',
#   'coverage term_insurance',
#   'coverage term_insurance policy',
#   'cross',
#   'cross thing',
#   'cross thing death_benefit',
#   'death',
#   'death insure',
#   'death insure individual',
#   'death_benefit',
#   'death_benefit company',
#   'death_benefit company bank',
#   'death_benefit exactly',
#   'death_benefit exactly insurance_company',
#   'depend',
#   'depend type',
#   'depend type policy',
#   'exactly',
#   'exactly insurance_company',
#   'exactly insurance_company goal',
#   'financial',
#   'financial coverage',
#   'financial coverage term_insurance',
#   'goal',
#   'goal policy',
#   'goal policy company',
#   'good',
#   'good morning',
#   'good morning help',
#   'hello',
#   'hello good',
#   'hello good morning',
#   'help',
#   'help want',
#   'help want term_insurance',
#   'history',
#   'history nice',
#   'history nice statement',
#   'holder',
#   'holder specific',
#   'holder specific time',
#   'individual',
#   'individual policy',
#   'individual policy term',
#   'insurance',
#   'insurance product',
#   'insurance product offer',
#   'insurance_company',
#   'insurance_company apply',
#   'insurance_company apply online',
#   'insurance_company goal',
#   'insurance_company goal policy',
#   'insurance_company offer',
#   'insurance_company offer financial',
#   'insure',
#   'insure individual',
#   'insure individual policy',
#   'life',
#   'life insurance',
#   'life insurance product',
#   'monthly',
#   'monthly visor',
#   'monthly visor quarterly',
#   'morning',
#   'morning help',
#   'morning help want',
#   'nice',
#   'nice statement',
#   'offer',
#   'offer financial',
#   'offer financial coverage',
#   'offer insurance_company',
#   'offer insurance_company offer',
#   'online',
#   'online apply',
#   'online apply online',
#   'online possible',
#   'online possible alright',
#   'period',
#   'period case',
#   'period case death',
#   'policy',
#   'policy benefit',
#   'policy benefit term_insurance',
#   'policy company',
#   'policy company insurance_company',
#   'policy holder',
#   'policy holder specific',
#   'policy term',
#   'policy term death_benefit',
#   'policy want',
#   'policy want usually',
#   'possible',
#   'possible alright',
#   'possible alright alright',
#   'premium',
#   'premium benefit',
#   'premium benefit actually',
#   'product',
#   'product offer',
#   'product offer insurance_company',
#   'quarterly',
#   'quarterly razor',
#   'quarterly razor yearly',
#   'razor',
#   'razor yearly',
#   'razor yearly wise',
#   'right',
#   'right premium',
#   'right premium benefit',
#   'share',
#   'share right',
#   'share right premium',
#   'specific',
#   'specific time',
#   'specific time period',
#   'statement',
#   'term',
#   'term death_benefit',
#   'term death_benefit company',
#   'term_insurance',
#   'term_insurance life',
#   'term_insurance life insurance',
#   'term_insurance policy',
#   'term_insurance policy benefit',
#   'term_insurance policy holder',
#   'thing',
#   'thing death_benefit',
#   'thing death_benefit exactly',
#   'time',
#   'time period',
#   'time period case',
#   'type',
#   'type policy',
#   'type policy want',
#   'usually',
#   'usually monthly',
#   'usually monthly visor',
#   'visor',
#   'visor quarterly',
#   'visor quarterly razor',
#   'want',
#   'want term_insurance',
#   'want term_insurance policy',
#   'want usually',
#   'want usually monthly',
#   'wise',
#   'wise benefit',
#   'wise benefit cross',
#   'yearly',
#   'yearly wise',
#   'yearly wise benefit'],
#  ['actually',
#   'actually know',
#   'actually know recommend',
#   'actually want',
#   'actually want know',
#   'afternoon',
#   'afternoon welcome',
#   'afternoon welcome life',
#   'assume',
#   'assume platinum',
#   'assume platinum high',
#   'available',
#   'available rupee',
#   'burden',
#   'burden monthly',
#   'burden monthly plan',
#   'depend',
#   'depend different',
#   'depend different premium',
#   'depend plan',
#   'depend plan premium',
#   'differ',
#   'differ assume',
#   'differ assume platinum',
#   'difference',
#   'difference difference',
#   'difference difference madam_uh',
#   'difference madam_uh',
#   'difference madam_uh depend',
#   'different',
#   'different premium',
#   'different premium know',
#   'easy',
#   'easy health',
#   'easy health insurance',
#   'easy plan',
#   'easy plan plan',
#   'exactly',
#   'exactly difference',
#   'exactly difference difference',
#   'fine',
#   'fine think',
#   'fine think premium',
#   'frequency',
#   'frequency plan',
#   'frequency plan monthly',
#   'gold',
#   'gold silver',
#   'gold silver platinum',
#   'good',
#   'good afternoon',
#   'good afternoon welcome',
#   'health',
#   'health insurance',
#   'health insurance madam_uh',
#   'help',
#   'help actually',
#   'help actually want',
#   'high',
#   'high think',
#   'high think platinum',
#   'insurance',
#   'insurance help',
#   'insurance help actually',
#   'insurance madam_uh',
#   'insurance madam_uh know',
#   'know',
#   'know look',
#   'know look monthly',
#   'know phone',
#   'know phone number',
#   'know recommend',
#   'know recommend recommend',
#   'know regard',
#   'know regard easy',
#   'life',
#   'life insurance',
#   'life insurance help',
#   'look',
#   'look monthly',
#   'look monthly premium',
#   'look option',
#   'look option gold',
#   'madam_uh',
#   'madam_uh depend',
#   'madam_uh depend plan',
#   'madam_uh know',
#   'madam_uh know phone',
#   'maximum',
#   'maximum payout',
#   'maximum payout available',
#   'minimum',
#   'minimum premium',
#   'minimum premium rupee',
#   'mobile',
#   'mobile number',
#   'mobile number easy',
#   'monthly',
#   'monthly plan',
#   'monthly plan perfect',
#   'monthly premium',
#   'monthly premium plan',
#   'monthly yearly',
#   'monthly yearly depend',
#   'number',
#   'number easy',
#   'number easy plan',
#   'number mobile',
#   'number mobile number',
#   'option',
#   'option gold',
#   'option gold silver',
#   'payment',
#   'payment frequency',
#   'payment frequency plan',
#   'payout',
#   'payout available',
#   'payout available rupee',
#   'perfect',
#   'perfect fine',
#   'perfect fine think',
#   'phone',
#   'phone number',
#   'phone number mobile',
#   'plan',
#   'plan burden',
#   'plan burden monthly',
#   'plan look',
#   'plan look option',
#   'plan monthly',
#   'plan monthly yearly',
#   'plan perfect',
#   'plan perfect fine',
#   'plan plan',
#   'plan plan look',
#   'plan premium',
#   'plan premium differ',
#   'plan quarterly',
#   'plan quarterly yearly',
#   'platinum',
#   'platinum exactly',
#   'platinum exactly difference',
#   'platinum high',
#   'platinum high think',
#   'platinum minimum',
#   'platinum minimum premium',
#   'platinum platinum',
#   'platinum platinum minimum',
#   'premium',
#   'premium differ',
#   'premium differ assume',
#   'premium know',
#   'premium know look',
#   'premium maximum',
#   'premium maximum payout',
#   'premium plan',
#   'premium plan quarterly',
#   'premium premium',
#   'premium premium maximum',
#   'premium rupee',
#   'premium rupee payment',
#   'quarterly',
#   'quarterly plan',
#   'quarterly plan burden',
#   'quarterly yearly',
#   'quarterly yearly actually',
#   'recommend',
#   'recommend quarterly',
#   'recommend quarterly plan',
#   'recommend recommend',
#   'recommend recommend quarterly',
#   'regard',
#   'regard easy',
#   'regard easy health',
#   'rupee',
#   'rupee payment',
#   'rupee payment frequency',
#   'silver',
#   'silver platinum',
#   'silver platinum exactly',
#   'think',
#   'think platinum',
#   'think platinum platinum',
#   'think premium',
#   'think premium premium',
#   'want',
#   'want know',
#   'want know regard',
#   'welcome',
#   'welcome life',
#   'welcome life insurance',
#   'yearly',
#   'yearly actually',
#   'yearly actually know',
#   'yearly depend',
#   'yearly depend different'],
#  ['account',
#   'account sorry',
#   'account sorry right',
#   'afternoon',
#   'afternoon life',
#   'afternoon life customer',
#   'agent',
#   'agent term',
#   'agent term payment',
#   'apologize',
#   'apologize inconvenience',
#   'apologize inconvenience verification',
#   'apply',
#   'apply insurance',
#   'apply insurance brochure',
#   'assist',
#   'assist life',
#   'assist life good',
#   'aware',
#   'aware time',
#   'aware time information',
#   'brochure',
#   'brochure assist',
#   'brochure assist life',
#   'brochure require',
#   'brochure require sail',
#   'care',
#   'care help',
#   'care help today',
#   'check',
#   'check toll_free',
#   'check toll_free number',
#   'claim',
#   'claim check',
#   'claim check toll_free',
#   'claim hour',
#   'claim hour process',
#   'claim insurance',
#   'claim insurance think',
#   'claim request',
#   'claim request record',
#   'claim response',
#   'claim response know',
#   'customer',
#   'customer care',
#   'customer care help',
#   'good',
#   'good afternoon',
#   'good afternoon life',
#   'happen',
#   'happen apologize',
#   'happen apologize inconvenience',
#   'heavy',
#   'heavy mention',
#   'heavy mention thing',
#   'help',
#   'help today',
#   'help today pension',
#   'hour',
#   'hour process',
#   'hour process heavy',
#   'inconvenience',
#   'inconvenience verification',
#   'inconvenience verification purpose',
#   'information',
#   'information present',
#   'information present website',
#   'insurance',
#   'insurance brochure',
#   'insurance brochure require',
#   'insurance reflect',
#   'insurance reflect account',
#   'insurance think',
#   'insurance think send',
#   'know',
#   'know claim',
#   'know claim insurance',
#   'know happen',
#   'know happen apologize',
#   'know policy_number',
#   'know policy_number policy_number',
#   'life',
#   'life customer',
#   'life customer care',
#   'life good',
#   'mention',
#   'mention thing',
#   'mention thing aware',
#   'number',
#   'number insurance',
#   'number insurance reflect',
#   'number request',
#   'number request claim',
#   'payment',
#   'payment know',
#   'payment know claim',
#   'payment term',
#   'payment term claim',
#   'pension',
#   'pension plus',
#   'pension plus policy',
#   'plus',
#   'plus policy',
#   'plus policy payment',
#   'policy',
#   'policy payment',
#   'policy payment term',
#   'policy_number',
#   'policy_number agent',
#   'policy_number agent term',
#   'policy_number policy_number',
#   'policy_number policy_number agent',
#   'present',
#   'present website',
#   'present website apply',
#   'process',
#   'process heavy',
#   'process heavy mention',
#   'purpose',
#   'purpose know',
#   'purpose know policy_number',
#   'record',
#   'record claim',
#   'record claim hour',
#   'reflect',
#   'reflect account',
#   'reflect account sorry',
#   'request',
#   'request claim',
#   'request claim request',
#   'request record',
#   'request record claim',
#   'require',
#   'require sail',
#   'require sail sorry',
#   'response',
#   'response know',
#   'response know happen',
#   'right',
#   'right claim',
#   'right claim check',
#   'sail',
#   'sail sorry',
#   'sail sorry brochure',
#   'send',
#   'send toll_free',
#   'send toll_free number',
#   'sorry',
#   'sorry brochure',
#   'sorry brochure assist',
#   'sorry right',
#   'sorry right claim',
#   'term',
#   'term claim',
#   'term claim response',
#   'term payment',
#   'term payment know',
#   'thing',
#   'thing aware',
#   'thing aware time',
#   'think',
#   'think send',
#   'think send toll_free',
#   'time',
#   'time information',
#   'time information present',
#   'today',
#   'today pension',
#   'today pension plus',
#   'toll_free',
#   'toll_free number',
#   'toll_free number insurance',
#   'toll_free number request',
#   'verification',
#   'verification purpose',
#   'verification purpose know',
#   'website',
#   'website apply',
#   'website apply insurance'],
#  ['agent',
#   'agent online',
#   'agent online easy',
#   'ahdfc',
#   'ahdfc life',
#   'ahdfc life help',
#   'assure',
#   'assure significant',
#   'assure significant stage',
#   'birth',
#   'birth birth',
#   'birth birth shell',
#   'birth jail',
#   'birth jail measure',
#   'birth shell',
#   'birth shell exeter',
#   'chance',
#   'chance link',
#   'chance link stock',
#   'claim',
#   'claim policy',
#   'claim policy premium',
#   'cover',
#   'cover option',
#   'cover option live',
#   'criterion',
#   'criterion minimum',
#   'criterion minimum year',
#   'easy',
#   'easy policy',
#   'easy policy chance',
#   'eligibility',
#   'eligibility criterion',
#   'eligibility criterion minimum',
#   'email',
#   'email policy',
#   'email policy want',
#   'enable',
#   'enable policyholder',
#   'enable policyholder increase',
#   'exeter',
#   'exeter pillar',
#   'exeter pillar post',
#   'extra_life',
#   'extra_life income_option',
#   'extra_life income_option option',
#   'feature',
#   'feature term_plan',
#   'feature term_plan enable',
#   'frequency',
#   'frequency monthly',
#   'frequency monthly quarterly',
#   'good',
#   'good interesting',
#   'good interesting option',
#   'half',
#   'half yearly',
#   'half yearly yearly',
#   'hello',
#   'hello ahdfc',
#   'hello ahdfc life',
#   'help',
#   'help term_plan',
#   'help term_plan provide',
#   'help want',
#   'help want know',
#   'history',
#   'history term_plan',
#   'history term_plan eligibility',
#   'income_option',
#   'income_option extra_life',
#   'income_option extra_life income_option',
#   'income_option option',
#   'income_option option good',
#   'increase',
#   'increase assure',
#   'increase assure significant',
#   'increase birth',
#   'increase birth jail',
#   'increase history',
#   'increase history term_plan',
#   'interesting',
#   'interesting option',
#   'interesting option life',
#   'jail',
#   'jail measure',
#   'jail measure increase',
#   'kevin',
#   'kevin help',
#   'kevin help term_plan',
#   'kevin kevin',
#   'kevin kevin help',
#   'kind',
#   'kind unit',
#   'kind unit link',
#   'know',
#   'know plus',
#   'know plus plan',
#   'life',
#   'life help',
#   'life help want',
#   'life marriage',
#   'life marriage birth',
#   'life option',
#   'life option income_option',
#   'life stage',
#   'life stage protection',
#   'link',
#   'link purely',
#   'link purely term',
#   'link stock',
#   'link stock market',
#   'live',
#   'live option_extra',
#   'live option_extra life',
#   'market',
#   'market kind',
#   'market kind unit',
#   'marriage',
#   'marriage birth',
#   'marriage birth birth',
#   'marriage measure',
#   'marriage measure increase',
#   'maximum',
#   'maximum year',
#   'maximum year politic',
#   'maximum year sort',
#   'measure',
#   'measure increase',
#   'measure increase birth',
#   'measure increase history',
#   'minimum',
#   'minimum year',
#   'minimum year maximum',
#   'month',
#   'month email',
#   'month email policy',
#   'monthly',
#   'monthly quarterly',
#   'monthly quarterly half',
#   'mouth',
#   'mouth month',
#   'mouth month email',
#   'online',
#   'online easy',
#   'online easy policy',
#   'option',
#   'option good',
#   'option good interesting',
#   'option income_option',
#   'option income_option extra_life',
#   'option life',
#   'option life stage',
#   'option live',
#   'option live option_extra',
#   'option_extra',
#   'option_extra life',
#   'option_extra life option',
#   'payment',
#   'payment frequency',
#   'payment frequency monthly',
#   'pillar',
#   'pillar post',
#   'pillar post marriage',
#   'plan',
#   'plan kevin',
#   'plan kevin kevin',
#   'plus',
#   'plus plan',
#   'plus plan kevin',
#   'policy',
#   'policy chance',
#   'policy chance link',
#   'policy premium',
#   'policy premium payment',
#   'policy term',
#   'policy term year',
#   'policy want',
#   'policy want agent',
#   'policyholder',
#   'policyholder increase',
#   'policyholder increase assure',
#   'politic',
#   'politic policy',
#   'politic policy term',
#   'post',
#   'post marriage',
#   'post marriage measure',
#   'premium',
#   'premium payment',
#   'premium payment frequency',
#   'protection',
#   'protection feature',
#   'protection feature term_plan',
#   'provide',
#   'provide cover',
#   'provide cover option',
#   'purely',
#   'purely term',
#   'purely term policy',
#   'quarterly',
#   'quarterly half',
#   'quarterly half yearly',
#   'shell',
#   'shell exeter',
#   'shell exeter pillar',
#   'significant',
#   'significant stage',
#   'significant stage life',
#   'sort',
#   'sort claim',
#   'sort claim policy',
#   'stage',
#   'stage life',
#   'stage life marriage',
#   'stage protection',
#   'stage protection feature',
#   'stock',
#   'stock market',
#   'stock market kind',
#   'term',
#   'term policy',
#   'term year',
#   'term year maximum',
#   'term_plan',
#   'term_plan eligibility',
#   'term_plan eligibility criterion',
#   'term_plan enable',
#   'term_plan enable policyholder',
#   'term_plan provide',
#   'term_plan provide cover',
#   'unit',
#   'unit link',
#   'unit link purely',
#   'want',
#   'want agent',
#   'want agent online',
#   'want know',
#   'want know plus',
#   'year',
#   'year maximum',
#   'year maximum year',
#   'year politic',
#   'year politic policy',
#   'year sort',
#   'year sort claim',
#   'yearly',
#   'yearly mouth',
#   'yearly mouth month',
#   'yearly yearly',
#   'yearly yearly mouth'],
#  ['card',
#   'card debit',
#   'card debit card',
#   'card online',
#   'card online wonderful',
#   'credit',
#   'credit card',
#   'credit card debit',
#   'cross',
#   'cross date',
#   'cross date premium',
#   'date',
#   'date premium',
#   'date premium issue',
#   'debit',
#   'debit card',
#   'debit card online',
#   'free',
#   'free payment',
#   'free payment thing',
#   'future',
#   'future premium',
#   'future premium payment',
#   'hassle',
#   'hassle free',
#   'hassle free payment',
#   'help',
#   'help moment',
#   'help moment register_online',
#   'help purchase',
#   'help purchase young',
#   'issue',
#   'issue future',
#   'issue future premium',
#   'issue net_banking',
#   'issue net_banking credit',
#   'kindly',
#   'kindly register_online',
#   'kindly register_online hassle',
#   'know',
#   'know payment',
#   'know payment help',
#   'know premium',
#   'know premium policy_number',
#   'mention',
#   'mention policy_number',
#   'mention remark',
#   'mention remark mention',
#   'moment',
#   'moment register_online',
#   'moment register_online time',
#   'net_banking',
#   'net_banking credit',
#   'net_banking credit card',
#   'net_banking issue',
#   'net_banking issue future',
#   'net_banking mention',
#   'net_banking mention remark',
#   'online',
#   'online wonderful',
#   'online wonderful payment',
#   'payment',
#   'payment help',
#   'payment help moment',
#   'payment kindly',
#   'payment kindly register_online',
#   'payment know',
#   'payment know payment',
#   'payment net_banking',
#   'payment net_banking issue',
#   'payment payment',
#   'payment payment know',
#   'payment thing',
#   'payment thing net_banking',
#   'plan',
#   'plan want',
#   'plan want know',
#   'policy_number',
#   'policy_number policy_number',
#   'policy_number policy_number quarterly',
#   'policy_number quarterly',
#   'policy_number quarterly payment',
#   'premium',
#   'premium issue',
#   'premium issue net_banking',
#   'premium payment',
#   'premium payment kindly',
#   'premium plan',
#   'premium plan want',
#   'premium policy_number',
#   'premium policy_number policy_number',
#   'purchase',
#   'purchase young',
#   'purchase young star',
#   'quarterly',
#   'quarterly payment',
#   'quarterly payment payment',
#   'register_online',
#   'register_online hassle',
#   'register_online hassle free',
#   'register_online time',
#   'register_online time cross',
#   'remark',
#   'remark mention',
#   'remark mention policy_number',
#   'star',
#   'star super',
#   'star super premium',
#   'super',
#   'super premium',
#   'super premium plan',
#   'thing',
#   'thing net_banking',
#   'thing net_banking mention',
#   'time',
#   'time cross',
#   'time cross date',
#   'want',
#   'want know',
#   'want know premium',
#   'welcome',
#   'welcome help',
#   'welcome help purchase',
#   'wonderful',
#   'wonderful payment',
#   'wonderful payment net_banking',
#   'young',
#   'young star',
#   'young star super'],
#  ['actually',
#   'actually write',
#   'actually write send',
#   'agent',
#   'agent document',
#   'agent document tomorrow',
#   'agent place',
#   'agent place soon',
#   'assist',
#   'assist thing',
#   'assist thing pickup',
#   'atfc',
#   'atfc life',
#   'atfc life help',
#   'caller',
#   'caller toll',
#   'caller toll free',
#   'card',
#   'card copy',
#   'card copy good',
#   'collect',
#   'collect document',
#   'collect document write',
#   'collect place',
#   'collect place representative',
#   'complete',
#   'complete agent',
#   'complete agent document',
#   'copy',
#   'copy good',
#   'copy good require',
#   'craig',
#   'craig want',
#   'craig want register',
#   'definitely',
#   'definitely form',
#   'definitely form send',
#   'document',
#   'document actually',
#   'document actually write',
#   'document collect',
#   'document collect place',
#   'document online',
#   'document online query',
#   'document require',
#   'document require passport',
#   'document tomorrow',
#   'document tomorrow insurance',
#   'document write',
#   'document write mail',
#   'fine',
#   'fine know',
#   'fine know time',
#   'form',
#   'form send',
#   'form send agent',
#   'free',
#   'free number',
#   'free number assist',
#   'good',
#   'good require',
#   'good require right',
#   'help',
#   'help craig',
#   'help craig want',
#   'insurance',
#   'insurance work',
#   'insurance work know',
#   'know',
#   'know document',
#   'know document require',
#   'know submit',
#   'know submit document',
#   'know time',
#   'know time process',
#   'know want',
#   'know want know',
#   'life',
#   'life caller',
#   'life caller toll',
#   'life help',
#   'life help craig',
#   'mail',
#   'mail state',
#   'mail state request',
#   'number',
#   'number assist',
#   'number assist thing',
#   'online',
#   'online query',
#   'online query life',
#   'passport',
#   'passport size',
#   'passport size photograph',
#   'photograph',
#   'photograph card',
#   'photograph card copy',
#   'pickup',
#   'pickup service',
#   'pickup service document',
#   'place',
#   'place representative',
#   'place representative collect',
#   'place soon',
#   'place soon possible',
#   'plan',
#   'plan know',
#   'plan know want',
#   'possible',
#   'process',
#   'process complete',
#   'process complete agent',
#   'query',
#   'query life',
#   'query life caller',
#   'register',
#   'register young',
#   'register young star',
#   'representative',
#   'representative collect',
#   'representative collect document',
#   'request',
#   'request fine',
#   'request fine know',
#   'require',
#   'require passport',
#   'require passport size',
#   'require right',
#   'require right definitely',
#   'right',
#   'right definitely',
#   'right definitely form',
#   'send',
#   'send agent',
#   'send agent place',
#   'send document',
#   'send document online',
#   'service',
#   'service document',
#   'service document collect',
#   'size',
#   'size photograph',
#   'size photograph card',
#   'soon',
#   'soon possible',
#   'star',
#   'star plan',
#   'star plan know',
#   'state',
#   'state request',
#   'state request fine',
#   'submit',
#   'submit document',
#   'submit document actually',
#   'thing',
#   'thing pickup',
#   'thing pickup service',
#   'time',
#   'time process',
#   'time process complete',
#   'toll',
#   'toll free',
#   'toll free number',
#   'tomorrow',
#   'tomorrow insurance',
#   'tomorrow insurance work',
#   'want',
#   'want know',
#   'want know submit',
#   'want register',
#   'want register young',
#   'welcome',
#   'welcome atfc',
#   'welcome atfc life',
#   'work',
#   'work know',
#   'work know document',
#   'write',
#   'write mail',
#   'write mail state',
#   'write send',
#   'write send document',
#   'young',
#   'young star',
#   'young star plan'],
#  ['afternoon',
#   'afternoon welcome',
#   'afternoon welcome insurance',
#   'cancer',
#   'cancer care',
#   'cancer care claim',
#   'care',
#   'care claim',
#   'care claim lightly',
#   'check',
#   'check problem',
#   'check problem maybe',
#   'claim',
#   'claim lightly',
#   'claim lightly sorry',
#   'claim process',
#   'claim process time',
#   'claim week',
#   'claim week response',
#   'close',
#   'close policy',
#   'close policy sorry',
#   'crazy',
#   'crazy person',
#   'crazy person cancer',
#   'damn',
#   'damn thing',
#   'damn thing past',
#   'dominate',
#   'dominate policy',
#   'dominate policy want',
#   'ease',
#   'ease claim',
#   'ease claim process',
#   'emily',
#   'emily policy',
#   'emily policy number',
#   'escalate',
#   'escalate matter',
#   'escalate matter supervisor',
#   'good',
#   'good afternoon',
#   'good afternoon welcome',
#   'help',
#   'help damn',
#   'help damn thing',
#   'help ease',
#   'help ease claim',
#   'help emily',
#   'help emily policy',
#   'help think',
#   'help think help',
#   'henceforth',
#   'henceforth uh_ok',
#   'henceforth uh_ok uh_let',
#   'inconvenience',
#   'inconvenience madam_uh',
#   'inconvenience madam_uh escalate',
#   'insurance',
#   'insurance help',
#   'insurance help emily',
#   'lightly',
#   'lightly sorry',
#   'lightly sorry plan',
#   'look',
#   'look solve',
#   'look solve matter',
#   'madam_uh',
#   'madam_uh escalate',
#   'madam_uh escalate matter',
#   'madam_uh wish',
#   'madam_uh wish close',
#   'matter',
#   'matter soon',
#   'matter soon possible',
#   'matter supervisor',
#   'matter supervisor look',
#   'maybe',
#   'maybe help',
#   'maybe help think',
#   'number',
#   'number upset',
#   'number upset claim',
#   'offer',
#   'offer help',
#   'offer help ease',
#   'past',
#   'past week',
#   'past week think',
#   'person',
#   'person cancer',
#   'person cancer care',
#   'plan',
#   'plan offer',
#   'plan offer help',
#   'policy',
#   'policy number',
#   'policy number upset',
#   'policy sorry',
#   'policy want',
#   'policy want relationship',
#   'possible',
#   'possible want',
#   'possible want split',
#   'premium',
#   'premium shut_policy',
#   'premium shut_policy uh_ok',
#   'problem',
#   'problem maybe',
#   'problem maybe help',
#   'process',
#   'process time',
#   'process time shut_policy',
#   'relationship',
#   'relationship henceforth',
#   'relationship henceforth uh_ok',
#   'renew',
#   'renew premium',
#   'renew premium shut_policy',
#   'renew sorry',
#   'renew sorry inconvenience',
#   'response',
#   'response term',
#   'response term want',
#   'shut_policy',
#   'shut_policy renew',
#   'shut_policy renew premium',
#   'shut_policy uh_ok',
#   'shut_policy uh_ok madam_uh',
#   'shut_policy want',
#   'shut_policy want renew',
#   'solve',
#   'solve matter',
#   'solve matter soon',
#   'soon',
#   'soon possible',
#   'soon possible want',
#   'sorry',
#   'sorry inconvenience',
#   'sorry inconvenience madam_uh',
#   'sorry plan',
#   'sorry plan offer',
#   'split',
#   'split want',
#   'split want dominate',
#   'supervisor',
#   'supervisor look',
#   'supervisor look solve',
#   'term',
#   'term want',
#   'term want shut_policy',
#   'thing',
#   'thing past',
#   'thing past week',
#   'think',
#   'think crazy',
#   'think crazy person',
#   'think help',
#   'think help damn',
#   'time',
#   'time shut_policy',
#   'time shut_policy renew',
#   'uh_let',
#   'uh_let check',
#   'uh_let check problem',
#   'uh_ok',
#   'uh_ok madam_uh',
#   'uh_ok madam_uh wish',
#   'uh_ok uh_let',
#   'uh_ok uh_let check',
#   'upset',
#   'upset claim',
#   'upset claim week',
#   'want',
#   'want dominate',
#   'want dominate policy',
#   'want relationship',
#   'want relationship henceforth',
#   'want renew',
#   'want renew sorry',
#   'want shut_policy',
#   'want shut_policy want',
#   'want split',
#   'want split want',
#   'week',
#   'week response',
#   'week response term',
#   'week think',
#   'week think crazy',
#   'welcome',
#   'welcome insurance',
#   'welcome insurance help',
#   'wish',
#   'wish close',
#   'wish close policy'],
#  ['actually',
#   'actually generally',
#   'actually generally monthly_wise',
#   'actually premium',
#   'actually premium month',
#   'away',
#   'away process',
#   'away process wait',
#   'change',
#   'change policy',
#   'change policy possible',
#   'confirmation',
#   'confirmation wait',
#   'confirmation wait right',
#   'conversation',
#   'conversation welcome',
#   'conversation welcome nice',
#   'convert',
#   'convert policy',
#   'convert policy quarterly',
#   'entire',
#   'entire surely',
#   'entire surely actually',
#   'evening',
#   'evening help',
#   'evening help actually',
#   'generally',
#   'generally monthly_wise',
#   'generally monthly_wise quarterly',
#   'good',
#   'good evening',
#   'good evening help',
#   'great',
#   'great convert',
#   'great convert policy',
#   'hello',
#   'hello good',
#   'hello good evening',
#   'help',
#   'help actually',
#   'help actually premium',
#   'mobile_number',
#   'mobile_number confirmation',
#   'mobile_number confirmation wait',
#   'mobile_number policy_number',
#   'mobile_number policy_number mobile_number',
#   'month',
#   'month want',
#   'month want entire',
#   'monthly_wise',
#   'monthly_wise great',
#   'monthly_wise great convert',
#   'monthly_wise quarterly',
#   'monthly_wise quarterly yearly',
#   'nice',
#   'payment',
#   'payment conversation',
#   'payment conversation welcome',
#   'play',
#   'play monthly_wise',
#   'play monthly_wise great',
#   'policy',
#   'policy possible',
#   'policy possible play',
#   'policy quarterly',
#   'policy quarterly thing',
#   'policy_number',
#   'policy_number mobile_number',
#   'policy_number mobile_number confirmation',
#   'policy_number mobile_number policy_number',
#   'possible',
#   'possible play',
#   'possible play monthly_wise',
#   'premium',
#   'premium month',
#   'premium month want',
#   'process',
#   'process wait',
#   'process wait payment',
#   'quarterly',
#   'quarterly thing',
#   'quarterly thing policy_number',
#   'quarterly yearly',
#   'quarterly yearly wise',
#   'right',
#   'right away',
#   'right away process',
#   'surely',
#   'surely actually',
#   'surely actually generally',
#   'thing',
#   'thing policy_number',
#   'thing policy_number mobile_number',
#   'wait',
#   'wait payment',
#   'wait payment conversation',
#   'wait right',
#   'wait right away',
#   'want',
#   'want change',
#   'want change policy',
#   'want entire',
#   'want entire surely',
#   'welcome',
#   'welcome nice',
#   'wise',
#   'wise want',
#   'wise want change',
#   'yearly',
#   'yearly wise',
#   'yearly wise want'],
#  ['agent',
#   'agent want',
#   'agent want arrange',
#   'angel',
#   'angel help',
#   'angel help hello',
#   'arrange',
#   'arrange callback',
#   'arrange callback want',
#   'asians',
#   'asians rhdfc',
#   'asians rhdfc contact',
#   'basically',
#   'basically year',
#   'basically year year',
#   'benefit',
#   'benefit similar',
#   'benefit similar contact',
#   'benefit sorry',
#   'benefit sorry company',
#   'benefit term_insurance',
#   'benefit term_insurance policy',
#   'callback',
#   'callback want',
#   'callback want process',
#   'check',
#   'check contact',
#   'check contact asians',
#   'company',
#   'company policy',
#   'company policy maintain',
#   'company service',
# ...
#   'correct address',
#   'correct address right_away',
#   'correct correct',
#   'correct correct account',
#   'correctly',
#   'correctly able',
#   'correctly able figure',
#   'expect',
#   'expect behavior',
#   'expect behavior expect',
#   'expect switch',
#   'expect switch check_right',
#   'figure',
#   'figure poly',
#   'figure poly policy_number',
#   'ford',
#   'ford policy_number',
#   'ford policy_number want',
#   'good',
#   'good afternoon',
#   'good afternoon help',
#   'good claim',
#   'good claim correct',
#   'happen',
#   'happen good',
#   'happen good claim',
#   'help',
#   'help claim',
#   'help claim term',
#   'holder',
#   'holder address',
#   'holder address thing',
#   'inconvenience',
#   'inconvenience brother',
#   'inconvenience brother phone',
#   'insurance',
#   'insurance soul',
#   'insurance soul brother',
#   'know',
#   'know thing',
#   'know thing correct',
#   'maybe',
#   'maybe check_right',
#   'maybe check_right away',
#   'number',
#   'number authentication',
#   'number authentication brother',
#   'number policy',
#   'number policy holder',
#   'phone',
#   'phone number',
#   'phone number authentication',
#   'policy',
#   'policy holder',
#   'policy holder address',
#   'policy_number',
#   'policy_number sorry',
#   'policy_number sorry happen',
#   'policy_number want',
#   'policy_number want know',
#   'poly',
#   'poly policy_number',
#   'poly policy_number sorry',
#   'process',
#   'process receive',
#   'process receive inconvenience',
#   'receive',
#   'receive inconvenience',
#   'receive inconvenience brother',
#   'right',
#   'right thing',
#   'right thing maybe',
#   'right_away',
#   'right_away right',
#   'right_away right thing',
#   'sorry',
#   'sorry happen',
#   'sorry happen good',
#   'soul',
#   'soul brother',
#   'soul brother claim',
#   'switch',
#   'switch check_right',
#   'switch check_right away',
#   'term',
#   'term insurance',
#   'term insurance soul',
#   'thing',
#   'thing correct',
#   'thing correct correct',
#   'thing correctly',
#   'thing correctly able',
#   'thing maybe',
#   'thing maybe check_right',
#   'type',
#   'type expect',
#   'type expect behavior',
#   'want',
#   'want know',
#   'want know thing'],
#  ['benefit',
#   'benefit quote',
#   'benefit quote legal_action',
#   'certainly',
#   'certainly registration',
#   'certainly registration policy_number',
#   'claim',
#   'claim benefit',
#   'claim benefit quote',
#   'claim plan',
#   'claim plan verification',
#   'claim policy',
#   'claim policy claim',
#   'claim ridiculous',
#   'claim ridiculous file',
#   'escalate',
#   'escalate legal_action',
#   'escalate supervisor',
#   'escalate supervisor manager',
#   'file',
#   'file claim',
#   'file claim policy',
#   'hello',
#   'hello life',
#   'hello life help',
#   'hello protect',
#   'hello protect plus',
#   'help',
#   'help escalate',
#   'help escalate supervisor',
#   'help hello',
#   'help hello protect',
#   'know',
#   'know escalate',
#   'know escalate legal_action',
#   'know policy_number',
#   'know policy_number mobile_number',
#   'legal_action',
#   'legal_action understand',
#   'legal_action understand problem',
#   'life',
#   'life help',
#   'life help hello',
#   'manager',
#   'manager want',
#   'manager want know',
#   'message',
#   'message somebody',
#   'message somebody claim',
#   'mobile_number',
#   'mobile_number certainly',
#   'mobile_number certainly registration',
#   'mobile_number claim',
#   'mobile_number claim ridiculous',
#   'mobile_number policy_number',
#   'mobile_number policy_number mobile_number',
#   'plan',
#   'plan somebody',
#   'plan somebody message',
#   'plan verification',
#   'plan verification purpose',
#   'plus',
#   'plus plan',
#   'plus plan somebody',
#   'policy',
#   'policy claim',
#   'policy claim benefit',
#   'policy_number',
#   'policy_number mobile_number',
#   'policy_number mobile_number certainly',
#   'policy_number mobile_number claim',
#   'policy_number mobile_number policy_number',
#   'problem',
#   'problem truth',
#   'problem truth help',
#   'protect',
#   'protect plus',
#   'protect plus plan',
#   'purpose',
#   'purpose know',
#   'purpose know policy_number',
#   'quote',
#   'quote legal_action',
#   'quote legal_action understand',
#   'registration',
#   'registration policy_number',
#   'registration policy_number mobile_number',
#   'ridiculous',
#   'ridiculous file',
#   'ridiculous file claim',
#   'somebody',
#   'somebody claim',
#   'somebody claim plan',
#   'somebody message',
#   'somebody message somebody',
#   'supervisor',
#   'supervisor manager',
#   'supervisor manager want',
#   'truth',
#   'truth help',
#   'truth help escalate',
#   'understand',
#   'understand problem',
#   'understand problem truth',
#   'verification',
#   'verification purpose',
#   'verification purpose know',
#   'want',
#   'want know',
#   'want know escalate'],
#  ['account',
#   'account hour',
#   'account hour know',
#   'afternoon',
#   'afternoon life',
#   'afternoon life customer',
#   'beat',
#   'beat policy_number',
#   'beat policy_number policy_number',
#   'benefit',
#   'benefit think',
#   'benefit think season',
#   'care',
#   'care help',
#   'care help today',
#   'claim',
#   'claim pension',
#   'claim pension plus',
#   'claim process',
#   'claim process fast',
#   'claim toll',
#   'claim toll free',
#   'complain',
#   'complain previously',
#   'complain previously know',
#   'customer',
#   'customer care',
#   'customer care help',
#   'easy',
#   'easy normal',
#   'easy normal people',
#   'escalate',
#   'escalate supervisor',
#   'escalate supervisor claim',
#   'fast',
#   'file',
#   'file plane',
#   'file plane process',
#   'free',
#   'free number',
#   'free number money',
#   'good',
#   'good afternoon',
#   'good afternoon life',
#   'happen',
#   'happen need',
#   'happen need sorry',
#   'help',
#   'help today',
#   'help today claim',
#   'hour',
#   'hour know',
#   'hour know happen',
#   'inconvenience',
#   'inconvenience beat',
#   'inconvenience beat policy_number',
#   'know',
#   'know claim',
#   'know claim toll',
#   'know happen',
#   'know happen need',
#   'know thing',
#   'know thing benefit',
#   'life',
#   'life customer',
#   'life customer care',
#   'money',
#   'money account',
#   'money account hour',
#   'month',
#   'month term',
#   'month term know',
#   'need',
#   'need escalate',
#   'need escalate supervisor',
#   'need sorry',
#   'need sorry inconvenience',
#   'normal',
#   'normal people',
#   'normal people file',
#   'number',
#   'number money',
#   'number money account',
#   'pension',
#   'pension plus',
#   'pension plus plan',
#   'people',
#   'people file',
#   'people file plane',
#   'plan',
#   'plan complain',
#   'plan complain previously',
#   'plane',
#   'plane process',
#   'plane process vietnam',
#   'plus',
#   'plus plan',
#   'plus plan complain',
#   'policy_number',
#   'policy_number policy_number',
#   'policy_number policy_number second',
#   'policy_number second',
#   'policy_number second month',
#   'previously',
#   'previously know',
#   'previously know claim',
#   'process',
#   'process fast',
#   'process vietnam',
#   'process vietnam need',
#   'season',
#   'season easy',
#   'season easy normal',
#   'second',
#   'second month',
#   'second month term',
#   'sorry',
#   'sorry inconvenience',
#   'sorry inconvenience beat',
#   'supervisor',
#   'supervisor claim',
#   'supervisor claim process',
#   'term',
#   'term know',
#   'term know thing',
#   'thing',
#   'thing benefit',
#   'thing benefit think',
#   'think',
#   'think season',
#   'think season easy',
#   'today',
#   'today claim',
#   'today claim pension',
#   'toll',
#   'toll free',
#   'toll free number',
#   'vietnam',
#   'vietnam need',
#   'vietnam need escalate'],
#  ['afternoon',
#   'afternoon help',
#   'afternoon help today',
#   'agent',
#   'agent mobile',
#   'agent mobile number',
#   'agent online',
#   'agent online procedure',
#   'agent want',
#   'agent want online',
#   'anytime',
#   'card',
#   'card card',
#   'card card ready',
#   'card ready',
#   'card ready need',
#   'card think',
#   'card think need',
#   'check',
#   'check come',
#   'check come home',
#   'click',
#   'click link',
#   'click link need',
#   'come',
#   'come check',
#   'come check come',
#   'come home',
#   'come home come',
#   'come home dude',
#   'come office',
#   'come office week',
#   'come problem',
#   'come problem question',
#   'come want',
#   'come want come',
#   'confirmation',
#   'confirmation mail',
#   'confirmation mail regard',
#   'customer',
#   'customer click',
#   'customer click link',
#   'doctor',
#   'doctor come',
#   'doctor come home',
#   'document',
#   'document need',
#   'document need upload',
#   'dude',
#   'dude service',
#   'dude service register',
#   'easy',
#   'easy procedure',
#   'easy procedure website',
#   'examiner',
#   'examiner come',
#   'examiner come check',
#   'follow',
#   'follow document',
#   'follow document need',
#   'garden',
#   'garden pond',
#   'garden pond card',
#   'good',
#   'good afternoon',
#   'good afternoon help',
#   'help',
#   'help easy',
#   'help easy procedure',
#   'help today',
#   'help today ohio',
#   'home',
#   'home come',
#   'home come office',
#   'home dude',
#   'home dude service',
#   'lake',
#   'lake pension',
#   'lake pension plus',
#   'link',
#   'link need',
#   'link need card',
#   'link register',
#   'link register customer',
#   'mail',
#   'mail regard',
#   'mail regard policy',
#   'mean',
#   'mean come',
#   'mean come want',
#   'medical',
#   'medical examiner',
#   'medical examiner come',
#   'medical plan',
#   'medical plan medical',
#   'medical thing',
#   'medical thing need',
#   'mind',
#   'mind anytime',
#   'mobile',
#   'mobile number',
#   'mobile number phone',
#   'need',
#   'need card',
#   'need card card',
#   'need separately',
#   'need separately doctor',
#   'need upload',
#   'need upload confirmation',
#   'need upload garden',
#   'need upload medical',
#   'number',
#   'number phone',
#   'number phone number',
#   'number pokémon',
#   'number pokémon send',
#   'office',
#   'office mean',
#   'office mean come',
#   'office week',
#   'office week office',
#   'ohio',
#   'ohio lake',
#   'ohio lake pension',
#   'online',
#   'online agent',
#   'online agent online',
#   'online online',
#   'online online agent',
#   'online procedure',
#   'online procedure help',
#   'online send',
#   'online send agent',
#   'pension',
#   'pension plus',
#   'pension plus plan',
#   'phone',
#   'phone number',
#   'phone number pokémon',
#   'plan',
#   'plan medical',
#   'plan medical examiner',
#   'plan processor',
#   'plan processor want',
#   'plan website',
#   'plan website upload',
#   'plus',
#   'plus plan',
#   'plus plan processor',
#   'pokémon',
#   'pokémon send',
#   'pokémon send agent',
#   'policy',
#   'policy step',
#   'policy step follow',
#   'pond',
#   'pond card',
#   'pond card think',
#   'possible',
#   'possible online',
#   'possible online send',
#   'problem',
#   'problem question',
#   'problem question mind',
#   'procedure',
#   'procedure help',
#   'procedure help easy',
#   'procedure website',
#   'procedure website link',
#   'processor',
#   'processor want',
#   'processor want possible',
#   'prompt',
#   'prompt regard',
#   'prompt regard medical',
#   'question',
#   'question mind',
#   'question mind anytime',
#   'ready',
#   'ready need',
#   'ready need upload',
#   'regard',
#   'regard medical',
#   'regard medical plan',
#   'regard policy',
#   'regard policy step',
#   'register',
#   'register customer',
#   'register customer click',
#   'register plan',
#   'register plan website',
#   'send',
#   'send agent',
#   'send agent mobile',
#   'send agent want',
#   'send prompt',
#   'send prompt regard',
#   'separately',
#   'separately doctor',
#   'separately doctor come',
#   'service',
#   'service register',
#   'service register plan',
#   'step',
#   'step follow',
#   'step follow document',
#   'thing',
#   'thing need',
#   'thing need separately',
#   'think',
#   'think need',
#   'think need upload',
#   'today',
#   'today ohio',
#   'today ohio lake',
#   'upload',
#   'upload confirmation',
#   'upload confirmation mail',
#   'upload garden',
#   'upload garden pond',
#   'upload medical',
#   'upload medical thing',
#   'upload send',
#   'upload send prompt',
#   'want',
#   'want come',
#   'want come problem',
#   'want online',
#   'want online online',
#   'want possible',
#   'want possible online',
#   'website',
#   'website link',
#   'website link register',
#   'website upload',
#   'website upload send',
#   'week',
#   'week office',
#   'week office mean'],
#  ['absolute_assignment',
#   'absolute_assignment conditional_assignment',
#   'absolute_assignment conditional_assignment absolute_assignment',
#   'absolute_assignment policy',
#   'absolute_assignment policy payment',
#   'alright',
#   'alright attach',
#   'alright attach policy',
#   'angel',
#   'angel phone_number',
#   'angel phone_number sorry',
#   'angel policy_number',
#   'angel policy_number query',
#   'anymore',
#   'anymore benefit',
#   'anymore benefit condition',
#   'assign',
#   'assign policy',
#   'assign policy assignment',
#   'assignee',
#   'assignee circumstance',
#   'assignee circumstance conditional_assignment',
#   'assigner',
#   'assigner different',
#   'assigner different anymore',
#   'assigning',
#   'assigning offend',
#   'assigning offend policy',
#   'assignment',
#   'assignment assign',
#   'assignment assign policy',
#   'assignment process',
#   'assignment process policyholder',
#   'assignment valuable',
#   'assignment valuable consideration',
#   'attach',
#   'attach policy',
#   'attach policy assigning',
#   'benefit',
#   'benefit condition',
#   'benefit condition thing',
#   'benefit policy',
#   'benefit policy assignee',
#   'child',
#   'child insurance',
#   'child insurance plan',
#   'circumstance',
#   'circumstance conditional_assignment',
#   'circumstance conditional_assignment policy',
#   'collateral',
#   'collateral loan',
#   'collateral loan assignment',
#   'condition',
#   'condition thing',
#   'condition thing conditional_assignment',
#   'conditional_assignment',
#   'conditional_assignment absolute_assignment',
#   'conditional_assignment absolute_assignment policy',
#   'conditional_assignment policy',
#   'conditional_assignment policy assigner',
#   'conditional_assignment typically',
#   'conditional_assignment typically insurance',
#   'consideration',
#   'different',
#   'different anymore',
#   'different anymore benefit',
#   'help',
#   'help high',
#   'help high angel',
#   'high',
#   'high angel',
#   'high angel policy_number',
#   'insurance',
#   'insurance plan',
#   'insurance plan offer',
#   'insurance policy',
#   'insurance policy collateral',
#   'know',
#   'know assignment',
#   'know assignment assign',
#   'know phone_number',
#   'know phone_number angel',
#   'life',
#   'life help',
#   'life help high',
#   'loan',
#   'loan assignment',
#   'loan assignment valuable',
#   'offend',
#   'offend policy',
#   'offend policy absolute_assignment',
#   'offer',
#   'offer verification',
#   'offer verification purpose',
#   'payment',
#   'payment benefit',
#   'payment benefit policy',
#   'phone_number',
#   'phone_number angel',
#   'phone_number angel phone_number',
#   'phone_number sorry',
#   'phone_number sorry repeat',
#   'plan',
#   'plan offer',
#   'plan offer verification',
#   'policy',
#   'policy absolute_assignment',
#   'policy absolute_assignment conditional_assignment',
#   'policy assignee',
#   'policy assignee circumstance',
#   'policy assigner',
#   'policy assigner different',
#   'policy assigning',
#   'policy assigning offend',
#   'policy assignment',
#   'policy assignment process',
#   'policy collateral',
#   'policy collateral loan',
#   'policy payment',
#   'policy payment benefit',
#   'policy_number',
#   'policy_number policy_number',
#   'policy_number policy_number want',
#   'policy_number query',
#   'policy_number query respect',
#   'policy_number want',
#   'policy_number want know',
#   'policyholder',
#   'policyholder transfer',
#   'policyholder transfer alright',
#   'process',
#   'process policyholder',
#   'process policyholder transfer',
#   'purpose',
#   'purpose know',
#   'purpose know phone_number',
#   'query',
#   'query respect',
#   'query respect child',
#   'repeat',
#   'repeat policy_number',
#   'repeat policy_number policy_number',
#   'respect',
#   'respect child',
#   'respect child insurance',
#   'sorry',
#   'sorry repeat',
#   'sorry repeat policy_number',
#   'thing',
#   'thing conditional_assignment',
#   'thing conditional_assignment typically',
#   'transfer',
#   'transfer alright',
#   'transfer alright attach',
#   'typically',
#   'typically insurance',
#   'typically insurance policy',
#   'valuable',
#   'valuable consideration',
#   'verification',
#   'verification purpose',
#   'verification purpose know',
#   'want',
#   'want know',
#   'want know assignment',
#   'welcome',
#   'welcome life',
#   'welcome life help']]
